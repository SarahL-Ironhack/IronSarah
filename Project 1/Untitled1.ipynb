# %%
# First step we define the bording board as a dictionary : each key from 1 to 9 is linked to an empty value
gaming_board = {
    '1':' ','2':' ','3':' ',
    '4':' ','5':' ','6':' ',
    '7':' ','8':' ','9':' '}
print(gaming_board)

# this function calls de value from the gaming_board's keys and prints the result as well as the board lines. It will show if they are empty, X or O.
def board_visual(gaming_board):
    print(gaming_board['1'] + '|' + gaming_board['2'] + '|' + gaming_board['3'])
    print('-+-+-')
    print(gaming_board['4'] + '|' + gaming_board['5'] + '|' + gaming_board['6'])
    print('-+-+-')
    print(gaming_board['7'] + '|' + gaming_board['8'] + '|' + gaming_board['9'])

board_visual(gaming_board)

def playersturn():
    turn = 'X'
    count = 0
    
    #wins line to explicit all cases in which the player will win : three identical horizontal, vertical and diagonal caracters, except empty ones.
    wins = ((gaming_board['1'] == gaming_board['2'] == gaming_board['3'] != ' ') or (gaming_board['4'] == gaming_board['5'] == gaming_board['6']!= ' ') or (gaming_board['7'] == gaming_board['8'] == gaming_board['9']!= ' ') or (gaming_board['1'] == gaming_board['4'] == gaming_board['7']!= ' ') or(gaming_board['2'] == gaming_board['5'] == gaming_board['8']!= ' ') or (gaming_board['3'] == gaming_board['6'] == gaming_board['9']!= ' ') or (gaming_board['1'] == gaming_board['5'] == gaming_board['9']!= ' ') or (gaming_board['7'] == gaming_board['5'] == gaming_board['3']!= ' '))
    
    #players will play up to 9 times (total boxes in grid)
    for x in range(1,10):    
        
        #Ask player to imput a number between 1 and 9 (ideally we should add condition to not accept anything else than digits!). And show grid.
        print("It's your turn ", turn,". Please chose a number between 1 and 9: ")
        (board_visual(gaming_board))
        move = input('Please type a number between 1 and 9: ')
    
        if gaming_board[move]==' ':
            gaming_board[move]=(turn) # replace dict value with the X or O, depending on the player 
            count +=1
            if count == 9 and wins == False: 
                board_visual(gaming_board)
                print("Game Over")
                print("It's a tie!")
                break
            elif count >=5 and wins == True:
                board_visual(gaming_board)
                print("Game Over")
                print("Player "+turn+" won")
                break
            else:
                pass
            
        else:
            print('Please choose a free box')

        if turn == "X":
            turn = "O"
        else: 
            turn = "X"
    
    
playersturn()
# Out:
# {'1': ' ', '2': ' ', '3': ' ', '4': ' ', '5': ' ', '6': ' ', '7': ' ', '8': ' ', '9': ' '}
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# It's your turn  X . Please chose a number between 1 and 9:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Please type a number between 1 and 9: 1
# It's your turn  O . Please chose a number between 1 and 9:
# X| |
# -+-+-
#  | |
# -+-+-
#  | |
# Please type a number between 1 and 9: 6
# It's your turn  X . Please chose a number between 1 and 9:
# X| |
# -+-+-
#  | |O
# -+-+-
#  | |
# Please type a number between 1 and 9: 4
# It's your turn  O . Please chose a number between 1 and 9:
# X| |
# -+-+-
# X| |O
# -+-+-
#  | |
# Please type a number between 1 and 9: 2
# It's your turn  X . Please chose a number between 1 and 9:
# X|O|
# -+-+-
# X| |O
# -+-+-
#  | |
# Please type a number between 1 and 9: 7
# It's your turn  O . Please chose a number between 1 and 9:
# X|O|
# -+-+-
# X| |O
# -+-+-
# X| |
# ...

# %% [markdown]
# ##
