# %%
import json
import requests

response = requests.get('https://api.github.com/users/Ironhack/repos')
results = response.json()

print(results)
# Out:
# [{'id': 75170096, 'node_id': 'MDEwOlJlcG9zaXRvcnk3NTE3MDA5Ng==', 'name': '2048', 'full_name': 'ironhack/2048', 'private': False, 'owner': {'login': 'ironhack', 'id': 4854004, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ4NTQwMDQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4854004?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack', 'html_url': 'https://github.com/ironhack', 'followers_url': 'https://api.github.com/users/ironhack/followers', 'following_url': 'https://api.github.com/users/ironhack/following{/other_user}', 'gists_url': 'https://api.github.com/users/ironhack/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ironhack/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ironhack/subscriptions', 'organizations_url': 'https://api.github.com/users/ironhack/orgs', 'repos_url': 'https://api.github.com/users/ironhack/repos', 'events_url': 'https://api.github.com/users/ironhack/events{/privacy}', 'received_events_url': '
# ...

# %%
import pandas as pd
data = pd.DataFrame(results)
data.head(10)
# Out:
#           id                           node_id                     name  \
# 0   75170096  MDEwOlJlcG9zaXRvcnk3NTE3MDA5Ng==                     2048
# 1  197550983  MDEwOlJlcG9zaXRvcnkxOTc1NTA5ODM=  alfresco-keycloak-theme
# 2   57225749  MDEwOlJlcG9zaXRvcnk1NzIyNTc0OQ==            auth-exercise
# 3   56848097  MDEwOlJlcG9zaXRvcnk1Njg0ODA5Nw==                      bbq
# 4  122097049  MDEwOlJlcG9zaXRvcnkxMjIwOTcwNDk=    bcn-webdev-cheatsheet
# 5   96100950  MDEwOlJlcG9zaXRvcnk5NjEwMDk1MA==                 bindings
# 6   62580111  MDEwOlJlcG9zaXRvcnk2MjU4MDExMQ==      broken-link-website
# 7  150108250  MDEwOlJlcG9zaXRvcnkxNTAxMDgyNTA=               canvas-lms
# 8   44265416  MDEwOlJlcG9zaXRvcnk0NDI2NTQxNg==           characters-api
# 9   56841990  MDEwOlJlcG9zaXRvcnk1Njg0MTk5MA==           css-playground
#
#                           full_name  private  \
# 0                     ironhack/2048    False
# 1  ironhack/alfresco-keycloak-theme    False
# ...

# %%
data.fork.value_counts()
# Out:
# True     17
# False    13
# Name: fork, dtype: int64

# %%
results = response.json()
flattened_data = pd.json_normalize(results)
flattened_data
# Out:
#            id                           node_id  \
# 0    75170096  MDEwOlJlcG9zaXRvcnk3NTE3MDA5Ng==
# 1   197550983  MDEwOlJlcG9zaXRvcnkxOTc1NTA5ODM=
# 2    57225749  MDEwOlJlcG9zaXRvcnk1NzIyNTc0OQ==
# 3    56848097  MDEwOlJlcG9zaXRvcnk1Njg0ODA5Nw==
# 4   122097049  MDEwOlJlcG9zaXRvcnkxMjIwOTcwNDk=
# 5    96100950  MDEwOlJlcG9zaXRvcnk5NjEwMDk1MA==
# 6    62580111  MDEwOlJlcG9zaXRvcnk2MjU4MDExMQ==
# 7   150108250  MDEwOlJlcG9zaXRvcnkxNTAxMDgyNTA=
# 8    44265416  MDEwOlJlcG9zaXRvcnk0NDI2NTQxNg==
# 9    56841990  MDEwOlJlcG9zaXRvcnk1Njg0MTk5MA==
# 10  134574029  MDEwOlJlcG9zaXRvcnkxMzQ1NzQwMjk=
# 11  115990443  MDEwOlJlcG9zaXRvcnkxMTU5OTA0NDM=
# 12   96104549  MDEwOlJlcG9zaXRvcnk5NjEwNDU0OQ==
# 13   86328286  MDEwOlJlcG9zaXRvcnk4NjMyODI4Ng==
# 14   34860891  MDEwOlJlcG9zaXRvcnkzNDg2MDg5MQ==
# 15  139946618  MDEwOlJlcG9zaXRvcnkxMzk5NDY2MTg=
# 16   85951144  MDEwOlJlcG9zaXRvcnk4NTk1MTE0NA==
# 17   97860064  MDEwOlJlcG9zaXRvcnk5Nzg2MDA2NA==
# ...

# %%
array = list()
for item in flattened_data['language']:
    if item not in array:
        array.append(item)

print(array)
# Out:
# ['CSS', 'FreeMarker', 'Ruby', 'JavaScript', 'C++', 'HTML', None, 'TypeScript', 'Shell', 'TSQL']

# %%
import json
import requests

response = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits')
results = response.json()

# %%
commits = pd.json_normalize(results)
commits
# Out:
#                                          sha  \
# 0   1638e5506e6947b77bfe78761d345476ae80d017
# 1   f332b5e6fcea965dc80f62220d7ee1457b04b90d
# 2   4c048c3efc18cf9d50e34c76919c8049ee7f2dbd
# 3   41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310
# 4   750eb91e4535c14ec4bf03f60cb5756a1c93f68f
# 5   4a8cc3cb64821cb58182a3a94be38f17d27a8e8f
# 6   1501bac01f8183d223a47ca7f23649a5d98d7e00
# 7   6c2a1247d4e13a37261081279f250ffa82ed5c96
# 8   cc02db3df76c8a16ecee3f7a937366ff427a7c3a
# 9   49ba929952728ab17635591cf55137c8af01babb
# 10  ba93368ee5593b15c7b1829f82cbacb9a003476c
# 11  2034c389cb81f30d30f94acc2a5237377d387dc1
# 12  09cf3f0163fe3895128cb322f5450672435ede7e
# 13  825dea0b3aab60bf587130441fab30d8abab775c
# 14  ced5e055e9313f60c57a7daab4ee89eac9f2c409
# 15  2cda9ab92b0f4dbfbe72e39a1bc26b9d7e41d28f
# 16  2db6ca9372c8585a0a894cef5c8be3c51a4547a7
# 17  4887dd8d4b582f6279c6f23114842d3fd071e62a
# 18  14a4c26acde03b2ebff1e1e84da29d60bc532410
# 19  b57627cc8931bdeb56b48bd853beac0b569e6e93
# ...

# %%
commits['commit.author.date'].count()
# Out:
# 30

# %%
search = response.json()
flattened_data = pd.json_normalize(results)
flattened_data
# Out:
#                                          sha  \
# 0   1638e5506e6947b77bfe78761d345476ae80d017
# 1   f332b5e6fcea965dc80f62220d7ee1457b04b90d
# 2   4c048c3efc18cf9d50e34c76919c8049ee7f2dbd
# 3   41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310
# 4   750eb91e4535c14ec4bf03f60cb5756a1c93f68f
# 5   4a8cc3cb64821cb58182a3a94be38f17d27a8e8f
# 6   1501bac01f8183d223a47ca7f23649a5d98d7e00
# 7   6c2a1247d4e13a37261081279f250ffa82ed5c96
# 8   cc02db3df76c8a16ecee3f7a937366ff427a7c3a
# 9   49ba929952728ab17635591cf55137c8af01babb
# 10  ba93368ee5593b15c7b1829f82cbacb9a003476c
# 11  2034c389cb81f30d30f94acc2a5237377d387dc1
# 12  09cf3f0163fe3895128cb322f5450672435ede7e
# 13  825dea0b3aab60bf587130441fab30d8abab775c
# 14  ced5e055e9313f60c57a7daab4ee89eac9f2c409
# 15  2cda9ab92b0f4dbfbe72e39a1bc26b9d7e41d28f
# 16  2db6ca9372c8585a0a894cef5c8be3c51a4547a7
# 17  4887dd8d4b582f6279c6f23114842d3fd071e62a
# 18  14a4c26acde03b2ebff1e1e84da29d60bc532410
# 19  b57627cc8931bdeb56b48bd853beac0b569e6e93
# ...

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
# search code searcher for query items inside of a file
# q = query so here .scavengerhunt
# in:path (keyword - what)
# +repo:ironhack-datalabs/scavenger (qualifier - here: where)

# %%
search=response.json()

# %%
search
# Out:
# {'total_count': 0, 'incomplete_results': False, 'items': []}

# %%
data= search['name']
print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-8db2994a0f3a> in <module>
# ----> 1 data= search['name']
#       2 print(data)
#
# KeyError: 'name'
