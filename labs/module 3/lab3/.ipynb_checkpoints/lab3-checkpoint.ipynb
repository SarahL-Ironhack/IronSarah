# %%
import pandas as pd
import numpy as np
flowers = pd.read_csv(r"C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_3\3. Data-Cleaning-Challenge\iris-data.csv")

# %%
flowers.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
flowers.dtypes
# ok
# Out:
# sepal_length_cm    float64
# sepal_width_cm     float64
# petal_length_cm    float64
# petal_width_cm     float64
# class               object
# dtype: object

# %%
flowers[flowers.isnull().any(axis=1)]
# 5 missing values
flowers.drop([7,8,9,10,11], inplace=True)

# %%
flowers[flowers.isnull().any(axis=1)]
#checking all has been dropped - ok
# Out:
# Empty DataFrame
# Columns: [sepal_length_cm, sepal_width_cm, petal_length_cm, petal_width_cm, class]
# Index: []

# %%
flowers.describe()
# no columns with 0 variance - ok
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       145.000000      145.000000       145.000000      145.000000
# mean          5.670303        3.046207         3.836552        1.236552
# std           1.326540        0.435096         1.742955        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.800000        3.000000         4.400000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
duplicateRowsDF = flowers[flowers.duplicated()]
duplicateRowsDF
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 37               4.9             3.1              1.5             0.1
# 142              5.8             2.7              5.1             1.9
#
#               class
# 37      Iris-setosa
# 142  Iris-virginica

# %%
flowers.drop([37,142], inplace=True)

# %%
flowers.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       143.000000      143.000000       143.000000      143.000000
# mean          5.674783        3.048252         3.844056        1.239860
# std           1.334232        0.437157         1.740957        0.752287
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.800000        3.000000         4.400000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
flowers['class'].value_counts()
# Out:
# Iris-virginica     49
# Iris-versicolor    45
# Iris-setosa        43
# versicolor          5
# Iris-setossa        1
# Name: class, dtype: int64

# %%
flowers['class'] = np.where(flowers['class']=='versicolor', 'Iris-versicolor', flowers['class'])
flowers['class'] = np.where(flowers['class']=='Iris-setossa', 'Iris-setosa', flowers['class'])

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
#Encode Education
flowers["class_enc"] = label.fit_transform(flowers["class"])

# %%
flowers.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# count       143.000000      143.000000       143.000000      143.000000
# mean          5.674783        3.048252         3.844056        1.239860
# std           1.334232        0.437157         1.740957        0.752287
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.800000        3.000000         4.400000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000
#
#         class_enc
# count  143.000000
# mean     1.034965
# std      0.808516
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %% [markdown]
# # Checking for outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=flowers['sepal_length_cm'])
# Out:
# <AxesSubplot:xlabel='sepal_length_cm'>

# %%
enc1 = flowers[flowers['class_enc']==1]
flowers['sepal_length_cm']=np.where(flowers['sepal_length_cm']<4, 
                                 enc1['sepal_length_cm'].mean(), flowers['sepal_length_cm'])

# %%
sns.boxplot(x=flowers['sepal_length_cm'])
# Out:
# <AxesSubplot:xlabel='sepal_length_cm'>

# %%
sns.boxplot(x=flowers['sepal_width_cm'])
# Out:
# <AxesSubplot:xlabel='sepal_width_cm'>

# %%
sns.boxplot(x=flowers['petal_length_cm'])
# Out:
# <AxesSubplot:xlabel='petal_length_cm'>

# %%
sns.boxplot(x=flowers['petal_width_cm'])
# Out:
# <AxesSubplot:xlabel='petal_width_cm'>

# %% [markdown]
# # Plot everything you can about the data

# %%
flowers.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class  class_enc
# 0  Iris-setosa          0
# 1  Iris-setosa          0
# 2  Iris-setosa          0
# 3  Iris-setosa          0
# 4  Iris-setosa          0

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x='sepal_length_cm',y='sepal_width_cm',hue='class',data=flowers).set_title('sepal length and width')
# Out:
# Text(0.5, 1.0, 'sepal length and width')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x='petal_length_cm',y='petal_width_cm',hue='class',data=flowers).set_title('petal length and width')
# Out:
# Text(0.5, 1.0, 'petal length and width')

# %%
flowers2 = flowers.drop(['class'], axis=1)
sns.heatmap(flowers2)
plt.show()

# %%
df_corr = flowers.corr()
df_corr
# Out:
#                  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# sepal_length_cm         1.000000       -0.081736         0.834368
# sepal_width_cm         -0.081736        1.000000        -0.411059
# petal_length_cm         0.834368       -0.411059         1.000000
# petal_width_cm          0.788450       -0.346795         0.958337
# class_enc               0.761797       -0.409273         0.945975
#
#                  petal_width_cm  class_enc
# sepal_length_cm        0.788450   0.761797
# sepal_width_cm        -0.346795  -0.409273
# petal_length_cm        0.958337   0.945975
# petal_width_cm         1.000000   0.954049
# class_enc              0.954049   1.000000

# %%
np.ones_like(df_corr, dtype=np.bool)
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
fig, ax = plt.subplots(figsize=(10, 8))
# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# plot heatmap
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap='Blues',
           vmin=-1, vmax=1, cbar_kws={"shrink": .8})
# yticks
plt.yticks(rotation=0)
plt.show()
# Out:
# C:\Users\Sarah\AppData\Local\Temp/ipykernel_41756/1781087771.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.ones_like(df_corr, dtype=np.bool)
# C:\Users\Sarah\AppData\Local\Temp/ipykernel_41756/1781087771.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# ...

# %%
flowers.plot()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="sepal_width_cm", y="sepal_length_cm", hue = "class_enc", data=flowers)
# Out:
# <AxesSubplot:xlabel='sepal_width_cm', ylabel='sepal_length_cm'>

# %%
sns.scatterplot(x="petal_width_cm", y="petal_length_cm", hue = "class_enc", data=flowers)
# Out:
# <AxesSubplot:xlabel='petal_width_cm', ylabel='petal_length_cm'>

# %%
flowers.to_csv('csv_file.csv')
