# %% [markdown]
# # Parallelization Lab
# In this lab, you will be leveraging several concepts you have learned to obtain a list of links from a web page and crawl and index the pages referenced by those links - both sequentially and in parallel. Follow the steps below to complete the lab.

# %% [markdown]
# ### Step 1: Use the requests library to retrieve the content from the URL below.

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
# your code here
response = requests.get(url).content

# %% [markdown]
# ### Step 2: Use BeautifulSoup to extract a list of all the unique links on the page.

# %%
from bs4 import BeautifulSoup
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\sarah\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sarah\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)

# %%
# your code here
soup = BeautifulSoup(response, 'html.parser')
link =soup.find_all('a', href=True)
links=[]
for element in link:
    links.append(element['href'])
links
# Out:
# ['#mw-head',
#  '#searchInput',
#  '/wiki/Information_science',
#  '/wiki/File:PIA23792-1600x1200(1).jpg',
#  '/wiki/File:PIA23792-1600x1200(1).jpg',
#  '/wiki/Comet_NEOWISE',
#  '/wiki/Astronomical_survey',
#  '/wiki/Space_telescope',
#  '/wiki/Wide-field_Infrared_Survey_Explorer',
#  '/wiki/Machine_learning',
#  '/wiki/Data_mining',
#  '/wiki/File:Kernel_Machine.svg',
#  '/wiki/Statistical_classification',
#  '/wiki/Cluster_analysis',
#  '/wiki/Regression_analysis',
#  '/wiki/Anomaly_detection',
#  '/wiki/Data_Cleaning',
#  '/wiki/Automated_machine_learning',
#  '/wiki/Association_rule_learning',
#  '/wiki/Reinforcement_learning',
#  '/wiki/Structured_prediction',
#  '/wiki/Feature_engineering',
#  '/wiki/Feature_learning',
#  '/wiki/Online_machine_learning',
#  '/wiki/Semi-supervised_learning',
#  '/wiki/Unsupervised_learning',
#  '/wiki/Learning_to_rank',
#  '/wiki/Grammar_induction',
#  '/wiki/Supervised_learning',
#  '/wiki/Statistical_classification',
#  '/wiki/Regression_analysis',
#  '/wiki/Decision_tree_learning',
#  '/wiki/Ensemble_learning',
#  '/wiki/Bootstrap_aggregating',
#  '/wiki/Boosting_(machine_learning)',
#  '/wiki/Random_forest',
#  '/wiki/K-nearest_neighbors_algorithm',
#  '/wiki/Linear_regression',
#  '/wiki/Naive_Bayes_classifier',
#  '/wiki/Artificial_neural_network',
#  '/wiki/Logistic_regression',
#  '/wiki/Perceptron',
#  '/wiki/Relevance_vector_machine',
#  '/wiki/Support-vector_machine',
#  '/wiki/Cluster_analysis',
#  '/wiki/BIRCH',
#  '/wiki/CURE_algorithm',
#  '/wiki/Hierarchical_clustering',
#  '/wiki/K-means_clustering',
#  '/wiki/Expectation%E2%80%93maximization_algorithm',
#  '/wiki/DBSCAN',
#  '/wiki/OPTICS_algorithm',
#  '/wiki/Mean_shift',
#  '/wiki/Dimensionality_reduction',
#  '/wiki/Factor_analysis',
#  '/wiki/Canonical_correlation',
#  '/wiki/Independent_component_analysis',
#  '/wiki/Linear_discriminant_analysis',
#  '/wiki/Non-negative_matrix_factorization',
#  '/wiki/Principal_component_analysis',
#  '/wiki/Proper_generalized_decomposition',
#  '/wiki/T-distributed_stochastic_neighbor_embedding',
#  '/wiki/Structured_prediction',
#  '/wiki/Graphical_model',
#  '/wiki/Bayesian_network',
#  '/wiki/Conditional_random_field',
#  '/wiki/Hidden_Markov_model',
#  '/wiki/Anomaly_detection',
#  '/wiki/K-nearest_neighbors_classification',
#  '/wiki/Local_outlier_factor',
#  '/wiki/Artificial_neural_network',
#  '/wiki/Autoencoder',
#  '/wiki/Cognitive_computing',
#  '/wiki/Deep_learning',
#  '/wiki/DeepDream',
#  '/wiki/Multilayer_perceptron',
#  '/wiki/Recurrent_neural_network',
#  '/wiki/Long_short-term_memory',
#  '/wiki/Gated_recurrent_unit',
#  '/wiki/Echo_state_network',
#  '/wiki/Restricted_Boltzmann_machine',
#  '/wiki/Generative_adversarial_network',
#  '/wiki/Self-organizing_map',
#  '/wiki/Convolutional_neural_network',
#  '/wiki/U-Net',
#  '/wiki/Transformer_(machine_learning_model)',
#  '/wiki/Vision_transformer',
#  '/wiki/Spiking_neural_network',
#  '/wiki/Memtransistor',
#  '/wiki/Electrochemical_RAM',
#  '/wiki/Reinforcement_learning',
#  '/wiki/Q-learning',
#  '/wiki/State%E2%80%93action%E2%80%93reward%E2%80%93state%E2%80%93action',
#  '/wiki/Temporal_difference_learning',
#  '/wiki/Kernel_machines',
#  '/wiki/Bias%E2%80%93variance_tradeoff',
#  '/wiki/Computational_learning_theory',
#  '/wiki/Empirical_risk_minimization',
#  '/wiki/Occam_learning',
#  '/wiki/Probably_approximately_correct_learning',
#  '/wiki/Statistical_learning_theory',
#  '/wiki/Vapnik%E2%80%93Chervonenkis_theory',
#  '/wiki/Conference_on_Neural_Information_Processing_Systems',
#  '/wiki/International_Conference_on_Machine_Learning',
#  '/wiki/Machine_Learning_(journal)',
#  '/wiki/Journal_of_Machine_Learning_Research',
#  'https://arxiv.org/list/cs.LG/recent',
#  '/wiki/Glossary_of_artificial_intelligence',
#  '/wiki/List_of_datasets_for_machine-learning_research',
#  '/wiki/Outline_of_machine_learning',
#  '/wiki/Template:Machine_learning',
#  '/wiki/Template_talk:Machine_learning',
#  'https://en.wikipedia.org/w/index.php?title=Template:Machine_learning&action=edit',
#  '/wiki/Interdisciplinarity',
#  '/wiki/Knowledge',
#  '/wiki/Unstructured_data',
#  '#cite_note-1',
#  '#cite_note-2',
#  '/wiki/Data_mining',
#  '/wiki/Machine_learning',
#  '/wiki/Big_data',
#  '/wiki/Statistics',
#  '/wiki/Data_analysis',
#  '/wiki/Informatics',
#  '#cite_note-3',
#  '/wiki/Mathematics',
#  '/wiki/Statistics',
#  '/wiki/Computer_science',
#  '/wiki/Information_science',
#  '/wiki/Domain_knowledge',
#  '/wiki/Turing_Award',
#  '/wiki/Jim_Gray_(computer_scientist)',
#  '/wiki/Empirical_research',
#  '/wiki/Basic_research',
#  '/wiki/Computational_science',
#  '/wiki/Information_technology',
#  '/wiki/Information_explosion',
#  '#cite_note-TansleyTolle2009-4',
#  '#cite_note-BellHey2009-5',
#  '#cite_note-6',
#  '#Foundations',
#  '#Relationship_to_statistics',
#  '#Etymology',
#  '#Early_usage',
#  '#Modern_usage',
#  '#Technologies_and_techniques',
#  '#See_also',
#  '#References',
#  '/w/index.php?title=Data_science&action=edit&section=1',
#  '/wiki/Big_data',
#  '#cite_note-7',
#  '/wiki/Information_visualization',
#  '/wiki/Data_sonification',
#  '/wiki/Complex_systems',
#  '/wiki/Communication',
#  '#cite_note-8',
#  '#cite_note-9',
#  '/wiki/Nathan_Yau',
#  '/wiki/Ben_Fry',
#  '/wiki/Human%E2%80%93computer_interaction',
#  '#cite_note-10',
#  '#cite_note-11',
#  '/wiki/American_Statistical_Association',
#  '/wiki/Database',
#  '/wiki/Machine_learning',
#  '/wiki/Distributed_computing',
#  '#cite_note-12',
#  '/w/index.php?title=Data_science&action=edit&section=2',
#  '/wiki/Nate_Silver',
#  '#cite_note-13',
#  '#cite_note-14',
#  '/wiki/Vasant_Dhar',
#  '#cite_note-15',
#  '/wiki/Andrew_Gelman',
#  '/wiki/Columbia_University',
#  '#cite_note-16',
#  '/wiki/David_Donoho',
#  '#cite_note-:7-17',
#  '/w/index.php?title=Data_science&action=edit&section=3',
#  '/w/index.php?title=Data_science&action=edit&section=4',
#  '/wiki/John_Tukey',
#  '#cite_note-:7-17',
#  '/wiki/C.F._Jeff_Wu',
#  '#cite_note-18',
#  '/wiki/Montpellier_2_University',
#  '#cite_note-19',
#  '#cite_note-Murtagh_2018_14-20',
#  '/wiki/Peter_Naur',
#  '#cite_note-:0-21',
#  '#cite_note-:0-21',
#  '/wiki/C.F._Jeff_Wu',
#  '#cite_note-22',
#  '#cite_note-Murtagh_2018_14-20',
#  '#cite_note-:1-23',
#  '#cite_note-:0-21',
#  '/w/index.php?title=Data_science&action=edit&section=5',
#  '/wiki/William_S._Cleveland',
#  '#cite_note-24',
#  '#cite_note-:1-23',
#  '/wiki/Committee_on_Data_for_Science_and_Technology',
#  '#cite_note-:1-23',
#  '/wiki/American_Statistical_Association',
#  '#cite_note-25',
#  '/wiki/DJ_Patil',
#  '/wiki/Jeff_Hammerbacher',
#  '#cite_note-26',
#  '/wiki/National_Science_Board',
#  '#cite_note-27',
#  '#cite_note-28',
#  '/wiki/Big_data',
#  '#cite_note-:5-29',
#  '#cite_note-:6-30',
#  '/w/index.php?title=Data_science&action=edit&section=6',
#  '/wiki/Statistics#Methods',
#  '/wiki/Linear_regression',
#  '/wiki/Logistic_regression',
#  '/wiki/Decision_tree',
#  '/wiki/Support-vector_machine',
#  '/wiki/Cluster_analysis',
#  '/wiki/Dimensionality_reduction',
#  '/wiki/Machine_learning',
#  '/wiki/Naive_Bayes_classifier',
#  '/wiki/Bayes%27_theorem',
#  '/w/index.php?title=Data_science&action=edit&section=7',
#  '/wiki/International_Journal_of_Population_Data_Science',
#  '/w/index.php?title=Data_science&action=edit&section=8',
#  '#cite_ref-1',
#  'http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1145%2F2500499',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:6107147',
#  'https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  '#cite_ref-2',
#  '/wiki/Jeffrey_T._Leek',
#  'http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/',
#  'https://web.archive.org/web/20140102194117/http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/',
#  '#cite_ref-3',
#  'https://www.springer.com/book/9784431702085',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1007%2F978-4-431-65950-1_3',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/9784431702085',
#  '#cite_ref-TansleyTolle2009_4-0',
#  'https://books.google.com/books?id=oGs_AQAAIAAJ',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-9825442-0-4',
#  'https://web.archive.org/web/20170320193019/https://books.google.com/books?id=oGs_AQAAIAAJ',
#  '#cite_ref-BellHey2009_5-0',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1126%2Fscience.1170411',
#  '/wiki/ISSN_(identifier)',
#  '//www.worldcat.org/issn/0036-8075',
#  '/wiki/PMID_(identifier)',
#  '//pubmed.ncbi.nlm.nih.gov/19265007',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:9743327',
#  '#cite_ref-6',
#  'https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/',
#  '#cite_ref-7',
#  'http://www.datascienceassn.org/about-data-science',
#  '#cite_ref-8',
#  'https://www.oreilly.com/library/view/doing-data-science/9781449363871/ch01.html',
#  '#cite_ref-9',
#  'https://medriscoll.com/post/4740157098/the-three-sexy-skills-of-data-geeks',
#  '#cite_ref-10',
#  'https://flowingdata.com/2009/06/04/rise-of-the-data-scientist/',
#  '#cite_ref-11',
#  'https://benfry.com/phd/dissertation/2.html',
#  '#cite_ref-12',
#  'https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  '/wiki/American_Statistical_Association',
#  'https://web.archive.org/web/20190620184935/https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  '#cite_ref-13',
#  'https://www.statisticsviews.com/article/nate-silver-what-i-need-from-statisticians/',
#  '#cite_ref-14',
#  'http://priceonomics.com/whats-the-difference-between-data-science-and/',
#  '#cite_ref-15',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1145%2F2500499',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:6107147',
#  '#cite_ref-16',
#  'https://statmodeling.stat.columbia.edu/2013/11/14/statistics-least-important-part-data-science/',
#  '#cite_ref-:7_17-0',
#  '#cite_ref-:7_17-1',
#  'http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  '#cite_ref-18',
#  'https://www2.isye.gatech.edu/~jeffwu/publications/fazhan.pdf',
#  '#cite_ref-19',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-12-241770-4',
#  '/wiki/OCLC_(identifier)',
#  '//www.worldcat.org/oclc/489990740',
#  '/wiki/Category:CS1_maint:_others',
#  '#cite_ref-Murtagh_2018_14_20-0',
#  '#cite_ref-Murtagh_2018_14_20-1',
#  'https://doi.org/10.3390%2Fbdcc2020014',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.3390%2Fbdcc2020014',
#  '#cite_ref-:0_21-0',
#  '#cite_ref-:0_21-1',
#  '#cite_ref-:0_21-2',
#  'https://doi.org/10.1145%2F3076253',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1145%2F3076253',
#  '#cite_ref-22',
#  'http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  '#cite_ref-:1_23-0',
#  '#cite_ref-:1_23-1',
#  '#cite_ref-:1_23-2',
#  'https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/',
#  '#cite_ref-24',
#  'https://www.stat.purdue.edu/~wsc/',
#  '#cite_ref-25',
#  'https://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  '#cite_ref-26',
#  'https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century',
#  '/wiki/ISSN_(identifier)',
#  '//www.worldcat.org/issn/0017-8012',
#  '#cite_ref-27',
#  'https://www.nsf.gov/pubs/2005/nsb0540/',
#  '#cite_ref-28',
#  'https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/',
#  '#cite_ref-:5_29-0',
#  'https://www.forbes.com/sites/peterpham/2015/08/28/the-impacts-of-big-data-that-you-may-not-have-heard-of/',
#  '#cite_ref-:6_30-0',
#  'https://towardsdatascience.com/how-data-science-will-impact-future-of-businesses-7f11f5699c4d',
#  '/wiki/Template:Data',
#  '/wiki/Template_talk:Data',
#  'https://en.wikipedia.org/w/index.php?title=Template:Data&action=edit',
#  '/wiki/Data_(computing)',
#  '/wiki/Data_augmentation',
#  '/wiki/Data_analysis',
#  '/wiki/Data_archaeology',
#  '/wiki/Data_cleansing',
#  '/wiki/Data_collection',
#  '/wiki/Data_compression',
#  '/wiki/Data_corruption',
#  '/wiki/Data_curation',
#  '/wiki/Data_degradation',
#  '/wiki/Data_editing',
#  '/wiki/Extract,_transform,_load',
#  '/wiki/Extract,_load,_transform',
#  '/wiki/Data_extraction',
#  '/wiki/Data_transformation',
#  '/wiki/Data_loading',
#  '/wiki/Data_farming',
#  '/wiki/Data_format_management',
#  '/wiki/Data_fusion',
#  '/wiki/Data_integration',
#  '/wiki/Data_integrity',
#  '/wiki/Data_library',
#  '/wiki/Data_loss',
#  '/wiki/Data_management',
#  '/wiki/Data_migration',
#  '/wiki/Data_mining',
#  '/wiki/Data_pre-processing',
#  '/wiki/Data_preservation',
#  '/wiki/Information_privacy',
#  '/wiki/Data_recovery',
#  '/wiki/Data_reduction',
#  '/wiki/Data_retention',
#  '/wiki/Data_quality',
#  '/wiki/Data_scraping',
#  '/wiki/Data_scrubbing',
#  '/wiki/Data_security',
#  '/wiki/Data_steward',
#  '/wiki/Data_storage',
#  '/wiki/Data_validation',
#  '/wiki/Data_warehouse',
#  '/wiki/Data_wrangling',
#  'https://en.wikipedia.org/w/index.php?title=Data_science&oldid=1063001066',
#  '/wiki/Help:Category',
#  '/wiki/Category:Information_science',
#  '/wiki/Category:Computer_occupations',
#  '/wiki/Category:Computational_fields_of_study',
#  '/wiki/Category:Data_analysis',
#  '/wiki/Category:CS1_maint:_others',
#  '/wiki/Category:Articles_with_short_description',
#  '/wiki/Category:Short_description_matches_Wikidata',
#  '/wiki/Category:Use_dmy_dates_from_August_2021',
#  '/wiki/Special:MyTalk',
#  '/wiki/Special:MyContributions',
#  '/w/index.php?title=Special:CreateAccount&returnto=Data+science',
#  '/w/index.php?title=Special:UserLogin&returnto=Data+science',
#  '/wiki/Data_science',
#  '/wiki/Talk:Data_science',
#  '/wiki/Data_science',
#  '/w/index.php?title=Data_science&action=edit',
#  '/w/index.php?title=Data_science&action=history',
#  '/wiki/Main_Page',
#  '/wiki/Main_Page',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  '/wiki/Wikipedia:About',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '/wiki/Help:Contents',
#  '/wiki/Help:Introduction',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Special:WhatLinksHere/Data_science',
#  '/wiki/Special:RecentChangesLinked/Data_science',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Special:SpecialPages',
#  '/w/index.php?title=Data_science&oldid=1063001066',
#  '/w/index.php?title=Data_science&action=info',
#  '/w/index.php?title=Special:CiteThisPage&page=Data_science&id=1063001066&wpFormIdentifier=titleform',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463',
#  '/w/index.php?title=Special:DownloadAsPdf&page=Data_science&action=show-download-screen',
#  '/w/index.php?title=Data_science&printable=yes',
#  'https://commons.wikimedia.org/wiki/Category:Data_science',
#  'https://en.wikiversity.org/wiki/Data_science',
#  'https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA',
#  'https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi_(Data_Science)',
#  'https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%AA%E0%A6%BE%E0%A6%A4%E0%A7%8D%E0%A6%A4_%E0%A6%AC%E0%A6%BF%E0%A6%9C%E0%A7%8D%E0%A6%9E%E0%A6%BE%E0%A6%A8',
#  'https://bg.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D0%B8%D1%82%D0%B5',
#  'https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades',
#  'https://cs.wikipedia.org/wiki/Data_science',
#  'https://de.wikipedia.org/wiki/Data_Science',
#  'https://et.wikipedia.org/wiki/Andmeteadus',
#  'https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD',
#  'https://es.wikipedia.org/wiki/Ciencia_de_datos',
#  'https://eo.wikipedia.org/wiki/Datuma_scienco',
#  'https://eu.wikipedia.org/wiki/Datu_zientzia',
#  'https://fa.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%AF%D8%A7%D8%AF%D9%87%E2%80%8C%D9%87%D8%A7',
#  'https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es',
#  'https://ko.wikipedia.org/wiki/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4',
#  'https://hy.wikipedia.org/wiki/%D5%8F%D5%BE%D5%B5%D5%A1%D5%AC%D5%B6%D5%A5%D6%80%D5%AB_%D5%A3%D5%AB%D5%BF%D5%B8%D6%82%D5%A9%D5%B5%D5%B8%D6%82%D5%B6',
#  'https://hi.wikipedia.org/wiki/%E0%A4%86%E0%A4%81%E0%A4%95%E0%A4%A1%E0%A4%BC%E0%A4%BE_%E0%A4%B5%E0%A4%BF%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%A8',
#  'https://id.wikipedia.org/wiki/Ilmu_data',
#  'https://it.wikipedia.org/wiki/Scienza_dei_dati',
#  'https://he.wikipedia.org/wiki/%D7%9E%D7%93%D7%A2_%D7%94%D7%A0%D7%AA%D7%95%D7%A0%D7%99%D7%9D',
#  'https://kk.wikipedia.org/wiki/%D0%94%D0%B5%D1%80%D0%B5%D0%BA%D1%82%D0%B5%D1%80_%D1%82%D1%83%D1%80%D0%B0%D0%BB%D1%8B_%D2%93%D1%8B%D0%BB%D1%8B%D0%BC',
#  'https://lv.wikipedia.org/wiki/Datu_m%C4%81c%C4%ABba',
#  'https://mk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%BF%D0%BE%D0%B4%D0%B0%D1%82%D0%BE%D1%86%D0%B8',
#  'https://ms.wikipedia.org/wiki/Sains_data',
#  'https://my.wikipedia.org/wiki/%E1%80%A1%E1%80%81%E1%80%BB%E1%80%80%E1%80%BA%E1%80%A1%E1%80%9C%E1%80%80%E1%80%BA%E1%80%9E%E1%80%AD%E1%80%95%E1%80%B9%E1%80%95%E1%80%B6%E1%80%95%E1%80%8A%E1%80%AC',
#  'https://nl.wikipedia.org/wiki/Datawetenschap',
#  'https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9',
#  'https://pl.wikipedia.org/wiki/Danologia',
#  'https://pt.wikipedia.org/wiki/Ci%C3%AAncia_de_dados',
#  'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#  'https://simple.wikipedia.org/wiki/Data_science',
#  'https://fi.wikipedia.org/wiki/Datatiede',
#  'https://ta.wikipedia.org/wiki/%E0%AE%A4%E0%AE%B0%E0%AE%B5%E0%AF%81_%E0%AE%85%E0%AE%B1%E0%AE%BF%E0%AE%B5%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D',
#  'https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%97%E0%B8%A2%E0%B8%B2%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%82%E0%B9%89%E0%B8%AD%E0%B8%A1%E0%B8%B9%E0%B8%A5',
#  'https://tr.wikipedia.org/wiki/Veri_bilimi',
#  'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BF%D1%80%D0%BE_%D0%B4%D0%B0%D0%BD%D1%96',
#  'https://ur.wikipedia.org/wiki/%DA%88%DB%8C%D9%B9%D8%A7_%D8%B3%D8%A7%D8%A6%D9%86%D8%B3',
#  'https://vi.wikipedia.org/wiki/Khoa_h%E1%BB%8Dc_d%E1%BB%AF_li%E1%BB%87u',
#  'https://zh-yue.wikipedia.org/wiki/%E6%95%B8%E6%93%9A%E7%A7%91%E5%AD%B8',
#  'https://zh.wikipedia.org/wiki/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  '//creativecommons.org/licenses/by-sa/3.0/',
#  '//foundation.wikimedia.org/wiki/Terms_of_Use',
#  '//foundation.wikimedia.org/wiki/Privacy_policy',
#  '//www.wikimediafoundation.org/',
#  'https://foundation.wikimedia.org/wiki/Privacy_policy',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:General_disclaimer',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '//en.m.wikipedia.org/w/index.php?title=Data_science&mobileaction=toggle_view_mobile',
#  'https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  'https://stats.wikimedia.org/#/en.wikipedia.org',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement',
#  'https://wikimediafoundation.org/',
#  'https://www.mediawiki.org/']

# %% [markdown]
# ### Step 3: Use list comprehensions with conditions to clean the link list.
# There are two types of links, absolute and relative. Absolute links have the full URL and begin with http while relative links begin with a forward slash (/) and point to an internal page within the wikipedia.org domain. Clean the respective types of URLs as follows.
#
# Absolute Links: Create a list of these and remove any that contain a percentage sign (%).
#
# Relative Links: Create a list of these, add the domain to the link so that you have the full URL, and remove any that contain a percentage sign (%).
#
# Combine the list of absolute and relative links and ensure there are no duplicate

# %%
domain = 'http://wikipedia.org'

# %%
# your code here
abs_links = []
rel_links = []

for link in links:
    if "%" in link:
        links.remove(link)
    if link.startswith('http') == True:
        abs_links.append(link)
    else:
        rel_links.append(domain+link)
all_links = abs_links +rel_links

all_links = list(dict.fromkeys(all_links))

for i in all_links:
    if all_links.count(i) > 1:
        print(True)
    else:
        print('no duplicates')
# Out:
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates
# no duplicates

# %% [markdown]
# ### Step 4: Use the os library to create a folder called wikipedia and make that the current working directory.

# %%
import os

# %%
# your code here
os.mkdir('wikipedia')

# %%
os.chdir(r'C:\Users\Sarah\Documents\IronSarah\labs\module 1\lab33\wikipedia')
os.getcwd()
# Out:
# 'C:\\Users\\Sarah\\Documents\\IronSarah\\labs\\module 1\\lab33\\wikipedia'

# %% [markdown]
# ### Step 5: Write a function called index_page that accepts a link and does the following.
# Tries to request the content of the page referenced by that link.
#
# Slugifies the filename using the slugify function from the python-slugify library and adds a .html file extension.
#
#       If you don't already have the python-slugify library installed, you can pip install it as follows:
#       $ pip3 install python-slugify.
#
#       To import the slugify function, you would do the following: from slugify import slugify.
#
#       You can then slugify a link as follows slugify(link).
#
# Creates a file in the wikipedia folder using the slugified filename and writes the contents of the page to the file.
#
# If an exception occurs during the process above, just pass.

# %%
from slugify import slugify

# %%
# your code here
def index_page(link):
    link_response = requests.get(link)
    print(link_response)
    print(slugify(link),'.html')
    return

# %%
index_page('https://arxiv.org/list/cs.LG/recent')
# Out:
# <Response [200]>
# https-arxiv-org-list-cs-lg-recent html

# %% [markdown]
# ### Step 6: Sequentially loop through the list of links, running the index_page function each time.
# Remember to include %%time at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
# %%time
# your code here
result = map(index_page,all_links)
print(list(result))
# Out:
# <Response [200]>
# https-arxiv-org-list-cs-lg-recent html
# <Response [200]>
# https-en-wikipedia-org-w-index-php-title-template-machine-learning-action-edit html
# <Response [403]>
# http-cacm-acm-org-magazines-2013-12-169933-data-science-and-prediction-fulltext html
# <Response [200]>
# https-api-semanticscholar-org-corpusid-6107147 html
# <Response [200]>
# https-web-archive-org-web-20141109113411-http-cacm-acm-org-magazines-2013-12-169933-data-science-and-prediction-fulltext html
# <Response [404]>
# http-simplystatistics-org-2013-12-12-the-key-word-in-data-science-is-not-data-it-is-science html
# <Response [200]>
# https-web-archive-org-web-20140102194117-http-simplystatistics-org-2013-12-12-the-key-word-in-data-science-is-not-data-it-is-science html
# <Response [200]>
# https-www-springer-com-book-9784431702085 html
# <Response [200]>
# https-books-google-com-books-id-ogs-aqaaiaaj html
# <Response [200]>
# https-web-archive-org-web-20170320193019-https-books-google-com-books-id-ogs-aqaaiaaj html
# <Response [200]>
# https-api-semanticscholar-org-corpusid-9743327 html
# <Response [200]>
# https-hbr-org-2012-10-data-scientist-the-sexiest-job-of-the-21st-century html
# <Response [403]>
# http-www-datascienceassn-org-about-data-science html
# <Response [200]>
# https-www-oreilly-com-library-view-doing-data-science-9781449363871-ch01-html html
# <Response [200]>
# https-medriscoll-com-post-4740157098-the-three-sexy-skills-of-data-geeks html
# <Response [200]>
# https-flowingdata-com-2009-06-04-rise-of-the-data-scientist html
# <Response [200]>
# https-benfry-com-phd-dissertation-2-html html
# <Response [403]>
# https-magazine-amstat-org-blog-2015-10-01-asa-statement-on-the-role-of-statistics-in-data-science html
# <Response [200]>
# https-web-archive-org-web-20190620184935-https-magazine-amstat-org-blog-2015-10-01-asa-statement-on-the-role-of-statistics-in-data-science html
# <Response [403]>
# https-www-statisticsviews-com-article-nate-silver-what-i-need-from-statisticians html
# <Response [200]>
# http-priceonomics-com-whats-the-difference-between-data-science-and html
# <Response [403]>
# https-statmodeling-stat-columbia-edu-2013-11-14-statistics-least-important-part-data-science html
# <Response [200]>
# http-courses-csail-mit-edu-18-337-2015-docs-50yearsdatascience-pdf html
# <Response [200]>
# https-www2-isye-gatech-edu-jeffwu-publications-fazhan-pdf html
# <Response [200]>
# http-www2-isye-gatech-edu-jeffwu-presentations-datascience-pdf html
# <Response [200]>
# https-www-forbes-com-sites-gilpress-2013-05-28-a-very-short-history-of-data-science html
# <Response [200]>
# https-www-stat-purdue-edu-wsc html
# <Response [403]>
# https-magazine-amstat-org-blog-2016-06-01-datascience-2 html
# <Response [200]>
# https-hbr-org-2012-10-data-scientist-the-sexiest-job-of-the-21st-century html
# <Response [200]>
# https-www-nsf-gov-pubs-2005-nsb0540 html
# <Response [200]>
# https-www-forbes-com-sites-gilpress-2013-08-19-data-science-whats-the-half-life-of-a-buzzword html
# <Response [200]>
# https-www-forbes-com-sites-peterpham-2015-08-28-the-impacts-of-big-data-that-you-may-not-have-heard-of html
# <Response [200]>
# https-towardsdatascience-com-how-data-science-will-impact-future-of-businesses-7f11f5699c4d html
# <Response [200]>
# https-en-wikipedia-org-w-index-php-title-template-data-action-edit html
# <Response [200]>
# https-en-wikipedia-org-w-index-php-title-data-science-oldid-1063001066 html
# <Response [200]>
# https-donate-wikimedia-org-wiki-special-fundraiserredirector-utm-source-donate-utm-medium-sidebar-utm-campaign-c13-en-wikipedia-org-uselang-en html
# <Response [200]>
# https-www-wikidata-org-wiki-special-entitypage-q2374463 html
# <Response [200]>
# https-commons-wikimedia-org-wiki-category-data-science html
# <Response [200]>
# https-en-wikiversity-org-wiki-data-science html
# <Response [200]>
# https-cs-wikipedia-org-wiki-data-science html
# <Response [200]>
# https-de-wikipedia-org-wiki-data-science html
# <Response [200]>
# https-et-wikipedia-org-wiki-andmeteadus html
# <Response [200]>
# https-es-wikipedia-org-wiki-ciencia-de-datos html
# <Response [200]>
# https-eo-wikipedia-org-wiki-datuma-scienco html
# <Response [200]>
# https-eu-wikipedia-org-wiki-datu-zientzia html
# <Response [200]>
# https-id-wikipedia-org-wiki-ilmu-data html
# <Response [200]>
# https-it-wikipedia-org-wiki-scienza-dei-dati html
# <Response [200]>
# https-ms-wikipedia-org-wiki-sains-data html
# <Response [200]>
# https-nl-wikipedia-org-wiki-datawetenschap html
# <Response [200]>
# https-pl-wikipedia-org-wiki-danologia html
# <Response [200]>
# https-simple-wikipedia-org-wiki-data-science html
# <Response [200]>
# https-fi-wikipedia-org-wiki-datatiede html
# <Response [200]>
# https-tr-wikipedia-org-wiki-veri-bilimi html
# <Response [200]>
# https-www-wikidata-org-wiki-special-entitypage-q2374463-sitelinks-wikipedia html
# <Response [200]>
# https-foundation-wikimedia-org-wiki-privacy-policy html
# <Response [200]>
# https-www-mediawiki-org-wiki-special-mylanguage-how-to-contribute html
# <Response [200]>
# https-stats-wikimedia-org-en-wikipedia-org html
# <Response [200]>
# https-foundation-wikimedia-org-wiki-cookie-statement html
# <Response [200]>
# https-wikimediafoundation-org html
# <Response [200]>
# https-www-mediawiki-org html
# <Response [200]>
# http-wikipedia-org-mw-head html
# <Response [200]>
# http-wikipedia-org-searchinput html
# <Response [200]>
# http-wikipedia-org-wiki-information-science html
# <Response [200]>
# http-wikipedia-org-wiki-file-pia23792-1600x1200-1-jpg html
# <Response [200]>
# http-wikipedia-org-wiki-comet-neowise html
# <Response [200]>
# http-wikipedia-org-wiki-astronomical-survey html
# <Response [200]>
# http-wikipedia-org-wiki-space-telescope html
# <Response [200]>
# http-wikipedia-org-wiki-wide-field-infrared-survey-explorer html
# <Response [200]>
# http-wikipedia-org-wiki-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-data-mining html
# <Response [200]>
# http-wikipedia-org-wiki-file-kernel-machine-svg html
# <Response [200]>
# http-wikipedia-org-wiki-statistical-classification html
# <Response [200]>
# http-wikipedia-org-wiki-cluster-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-regression-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-anomaly-detection html
# <Response [200]>
# http-wikipedia-org-wiki-data-cleaning html
# <Response [200]>
# http-wikipedia-org-wiki-automated-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-association-rule-learning html
# <Response [200]>
# http-wikipedia-org-wiki-reinforcement-learning html
# <Response [200]>
# http-wikipedia-org-wiki-structured-prediction html
# <Response [200]>
# http-wikipedia-org-wiki-feature-engineering html
# <Response [200]>
# http-wikipedia-org-wiki-feature-learning html
# <Response [200]>
# http-wikipedia-org-wiki-online-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-semi-supervised-learning html
# <Response [200]>
# http-wikipedia-org-wiki-unsupervised-learning html
# <Response [200]>
# http-wikipedia-org-wiki-learning-to-rank html
# <Response [200]>
# http-wikipedia-org-wiki-grammar-induction html
# <Response [200]>
# http-wikipedia-org-wiki-supervised-learning html
# <Response [200]>
# http-wikipedia-org-wiki-decision-tree-learning html
# <Response [200]>
# http-wikipedia-org-wiki-ensemble-learning html
# <Response [200]>
# http-wikipedia-org-wiki-bootstrap-aggregating html
# <Response [200]>
# http-wikipedia-org-wiki-boosting-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-random-forest html
# <Response [200]>
# http-wikipedia-org-wiki-k-nearest-neighbors-algorithm html
# <Response [200]>
# http-wikipedia-org-wiki-linear-regression html
# <Response [200]>
# http-wikipedia-org-wiki-naive-bayes-classifier html
# <Response [200]>
# http-wikipedia-org-wiki-artificial-neural-network html
# <Response [200]>
# http-wikipedia-org-wiki-logistic-regression html
# <Response [200]>
# http-wikipedia-org-wiki-perceptron html
# <Response [200]>
# http-wikipedia-org-wiki-relevance-vector-machine html
# <Response [200]>
# http-wikipedia-org-wiki-support-vector-machine html
# <Response [200]>
# http-wikipedia-org-wiki-birch html
# <Response [200]>
# http-wikipedia-org-wiki-cure-algorithm html
# <Response [200]>
# http-wikipedia-org-wiki-hierarchical-clustering html
# <Response [200]>
# http-wikipedia-org-wiki-k-means-clustering html
# <Response [200]>
# http-wikipedia-org-wiki-dbscan html
# <Response [200]>
# http-wikipedia-org-wiki-optics-algorithm html
# <Response [200]>
# http-wikipedia-org-wiki-mean-shift html
# <Response [200]>
# http-wikipedia-org-wiki-dimensionality-reduction html
# <Response [200]>
# http-wikipedia-org-wiki-factor-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-canonical-correlation html
# <Response [200]>
# http-wikipedia-org-wiki-independent-component-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-linear-discriminant-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-non-negative-matrix-factorization html
# <Response [200]>
# http-wikipedia-org-wiki-principal-component-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-proper-generalized-decomposition html
# <Response [200]>
# http-wikipedia-org-wiki-t-distributed-stochastic-neighbor-embedding html
# <Response [200]>
# http-wikipedia-org-wiki-graphical-model html
# <Response [200]>
# http-wikipedia-org-wiki-bayesian-network html
# <Response [200]>
# http-wikipedia-org-wiki-conditional-random-field html
# <Response [200]>
# http-wikipedia-org-wiki-hidden-markov-model html
# <Response [200]>
# http-wikipedia-org-wiki-k-nearest-neighbors-classification html
# <Response [200]>
# http-wikipedia-org-wiki-local-outlier-factor html
# <Response [200]>
# http-wikipedia-org-wiki-autoencoder html
# <Response [200]>
# http-wikipedia-org-wiki-cognitive-computing html
# <Response [200]>
# http-wikipedia-org-wiki-deep-learning html
# <Response [200]>
# http-wikipedia-org-wiki-deepdream html
# <Response [200]>
# http-wikipedia-org-wiki-multilayer-perceptron html
# <Response [200]>
# http-wikipedia-org-wiki-recurrent-neural-network html
# <Response [200]>
# http-wikipedia-org-wiki-long-short-term-memory html
# <Response [200]>
# http-wikipedia-org-wiki-gated-recurrent-unit html
# <Response [200]>
# http-wikipedia-org-wiki-echo-state-network html
# <Response [200]>
# http-wikipedia-org-wiki-restricted-boltzmann-machine html
# <Response [200]>
# http-wikipedia-org-wiki-generative-adversarial-network html
# <Response [200]>
# http-wikipedia-org-wiki-self-organizing-map html
# <Response [200]>
# http-wikipedia-org-wiki-convolutional-neural-network html
# <Response [200]>
# http-wikipedia-org-wiki-u-net html
# <Response [200]>
# http-wikipedia-org-wiki-transformer-machine-learning-model html
# <Response [200]>
# http-wikipedia-org-wiki-vision-transformer html
# <Response [200]>
# http-wikipedia-org-wiki-spiking-neural-network html
# <Response [200]>
# http-wikipedia-org-wiki-memtransistor html
# <Response [200]>
# http-wikipedia-org-wiki-electrochemical-ram html
# <Response [200]>
# http-wikipedia-org-wiki-q-learning html
# <Response [200]>
# http-wikipedia-org-wiki-temporal-difference-learning html
# <Response [200]>
# http-wikipedia-org-wiki-kernel-machines html
# <Response [200]>
# http-wikipedia-org-wiki-computational-learning-theory html
# <Response [200]>
# http-wikipedia-org-wiki-empirical-risk-minimization html
# <Response [200]>
# http-wikipedia-org-wiki-occam-learning html
# <Response [200]>
# http-wikipedia-org-wiki-probably-approximately-correct-learning html
# <Response [200]>
# http-wikipedia-org-wiki-statistical-learning-theory html
# <Response [200]>
# http-wikipedia-org-wiki-conference-on-neural-information-processing-systems html
# <Response [200]>
# http-wikipedia-org-wiki-international-conference-on-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-machine-learning-journal html
# <Response [200]>
# http-wikipedia-org-wiki-journal-of-machine-learning-research html
# <Response [200]>
# http-wikipedia-org-wiki-glossary-of-artificial-intelligence html
# <Response [200]>
# http-wikipedia-org-wiki-list-of-datasets-for-machine-learning-research html
# <Response [200]>
# http-wikipedia-org-wiki-outline-of-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-template-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-template-talk-machine-learning html
# <Response [200]>
# http-wikipedia-org-wiki-interdisciplinarity html
# <Response [200]>
# http-wikipedia-org-wiki-knowledge html
# <Response [200]>
# http-wikipedia-org-wiki-unstructured-data html
# <Response [200]>
# http-wikipedia-org-cite-note-1 html
# <Response [200]>
# http-wikipedia-org-cite-note-2 html
# <Response [200]>
# http-wikipedia-org-wiki-big-data html
# <Response [200]>
# http-wikipedia-org-wiki-statistics html
# <Response [200]>
# http-wikipedia-org-wiki-data-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-informatics html
# <Response [200]>
# http-wikipedia-org-cite-note-3 html
# <Response [200]>
# http-wikipedia-org-wiki-mathematics html
# <Response [200]>
# http-wikipedia-org-wiki-computer-science html
# <Response [200]>
# http-wikipedia-org-wiki-domain-knowledge html
# <Response [200]>
# http-wikipedia-org-wiki-turing-award html
# <Response [200]>
# http-wikipedia-org-wiki-jim-gray-computer-scientist html
# <Response [200]>
# http-wikipedia-org-wiki-empirical-research html
# <Response [200]>
# http-wikipedia-org-wiki-basic-research html
# <Response [200]>
# http-wikipedia-org-wiki-computational-science html
# <Response [200]>
# http-wikipedia-org-wiki-information-technology html
# <Response [200]>
# http-wikipedia-org-wiki-information-explosion html
# <Response [200]>
# http-wikipedia-org-cite-note-tansleytolle2009-4 html
# <Response [200]>
# http-wikipedia-org-cite-note-bellhey2009-5 html
# <Response [200]>
# http-wikipedia-org-cite-note-6 html
# <Response [200]>
# http-wikipedia-org-foundations html
# <Response [200]>
# http-wikipedia-org-relationship-to-statistics html
# <Response [200]>
# http-wikipedia-org-etymology html
# <Response [200]>
# http-wikipedia-org-early-usage html
# <Response [200]>
# http-wikipedia-org-modern-usage html
# <Response [200]>
# http-wikipedia-org-technologies-and-techniques html
# <Response [200]>
# http-wikipedia-org-see-also html
# <Response [200]>
# http-wikipedia-org-references html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-1 html
# <Response [200]>
# http-wikipedia-org-cite-note-7 html
# <Response [200]>
# http-wikipedia-org-wiki-information-visualization html
# <Response [200]>
# http-wikipedia-org-wiki-data-sonification html
# <Response [200]>
# http-wikipedia-org-wiki-complex-systems html
# <Response [200]>
# http-wikipedia-org-wiki-communication html
# <Response [200]>
# http-wikipedia-org-cite-note-8 html
# <Response [200]>
# http-wikipedia-org-cite-note-9 html
# <Response [200]>
# http-wikipedia-org-wiki-nathan-yau html
# <Response [200]>
# http-wikipedia-org-wiki-ben-fry html
# <Response [200]>
# http-wikipedia-org-cite-note-10 html
# <Response [200]>
# http-wikipedia-org-cite-note-11 html
# <Response [200]>
# http-wikipedia-org-wiki-american-statistical-association html
# <Response [200]>
# http-wikipedia-org-wiki-database html
# <Response [200]>
# http-wikipedia-org-wiki-distributed-computing html
# <Response [200]>
# http-wikipedia-org-cite-note-12 html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-2 html
# <Response [200]>
# http-wikipedia-org-wiki-nate-silver html
# <Response [200]>
# http-wikipedia-org-cite-note-13 html
# <Response [200]>
# http-wikipedia-org-cite-note-14 html
# <Response [200]>
# http-wikipedia-org-wiki-vasant-dhar html
# <Response [200]>
# http-wikipedia-org-cite-note-15 html
# <Response [200]>
# http-wikipedia-org-wiki-andrew-gelman html
# <Response [200]>
# http-wikipedia-org-wiki-columbia-university html
# <Response [200]>
# http-wikipedia-org-cite-note-16 html
# <Response [200]>
# http-wikipedia-org-wiki-david-donoho html
# <Response [200]>
# http-wikipedia-org-cite-note-7-17 html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-3 html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-4 html
# <Response [200]>
# http-wikipedia-org-wiki-john-tukey html
# <Response [200]>
# http-wikipedia-org-wiki-c-f-jeff-wu html
# <Response [200]>
# http-wikipedia-org-cite-note-18 html
# <Response [200]>
# http-wikipedia-org-wiki-montpellier-2-university html
# <Response [200]>
# http-wikipedia-org-cite-note-19 html
# <Response [200]>
# http-wikipedia-org-cite-note-murtagh-2018-14-20 html
# <Response [200]>
# http-wikipedia-org-wiki-peter-naur html
# <Response [200]>
# http-wikipedia-org-cite-note-0-21 html
# <Response [200]>
# http-wikipedia-org-cite-note-22 html
# <Response [200]>
# http-wikipedia-org-cite-note-1-23 html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-5 html
# <Response [200]>
# http-wikipedia-org-wiki-william-s-cleveland html
# <Response [200]>
# http-wikipedia-org-cite-note-24 html
# <Response [200]>
# http-wikipedia-org-wiki-committee-on-data-for-science-and-technology html
# <Response [200]>
# http-wikipedia-org-cite-note-25 html
# <Response [200]>
# http-wikipedia-org-wiki-dj-patil html
# <Response [200]>
# http-wikipedia-org-wiki-jeff-hammerbacher html
# <Response [200]>
# http-wikipedia-org-cite-note-26 html
# <Response [200]>
# http-wikipedia-org-wiki-national-science-board html
# <Response [200]>
# http-wikipedia-org-cite-note-27 html
# <Response [200]>
# http-wikipedia-org-cite-note-28 html
# <Response [200]>
# http-wikipedia-org-cite-note-5-29 html
# <Response [200]>
# http-wikipedia-org-cite-note-6-30 html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-6 html
# <Response [200]>
# http-wikipedia-org-wiki-statistics-methods html
# <Response [200]>
# http-wikipedia-org-wiki-decision-tree html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-7 html
# <Response [200]>
# http-wikipedia-org-wiki-international-journal-of-population-data-science html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit-section-8 html
# <Response [200]>
# http-wikipedia-org-cite-ref-1 html
# <Response [200]>
# http-wikipedia-org-wiki-doi-identifier html
# <Response [200]>
# http-wikipedia-org-wiki-s2cid-identifier html
# <Response [200]>
# http-wikipedia-org-cite-ref-2 html
# <Response [200]>
# http-wikipedia-org-wiki-jeffrey-t-leek html
# <Response [200]>
# http-wikipedia-org-cite-ref-3 html
# <Response [200]>
# http-wikipedia-org-wiki-isbn-identifier html
# <Response [200]>
# http-wikipedia-org-wiki-special-booksources-9784431702085 html
# <Response [200]>
# http-wikipedia-org-cite-ref-tansleytolle2009-4-0 html
# <Response [200]>
# http-wikipedia-org-wiki-special-booksources-978-0-9825442-0-4 html
# <Response [200]>
# http-wikipedia-org-cite-ref-bellhey2009-5-0 html
# <Response [200]>
# http-wikipedia-org-wiki-issn-identifier html
# <Response [404]>
# http-wikipedia-org-www-worldcat-org-issn-0036-8075 html
# <Response [200]>
# http-wikipedia-org-wiki-pmid-identifier html
# <Response [404]>
# http-wikipedia-org-pubmed-ncbi-nlm-nih-gov-19265007 html
# <Response [200]>
# http-wikipedia-org-cite-ref-6 html
# <Response [200]>
# http-wikipedia-org-cite-ref-7 html
# <Response [200]>
# http-wikipedia-org-cite-ref-8 html
# <Response [200]>
# http-wikipedia-org-cite-ref-9 html
# <Response [200]>
# http-wikipedia-org-cite-ref-10 html
# <Response [200]>
# http-wikipedia-org-cite-ref-11 html
# <Response [200]>
# http-wikipedia-org-cite-ref-12 html
# <Response [200]>
# http-wikipedia-org-cite-ref-13 html
# <Response [200]>
# http-wikipedia-org-cite-ref-14 html
# <Response [200]>
# http-wikipedia-org-cite-ref-15 html
# <Response [200]>
# http-wikipedia-org-cite-ref-16 html
# <Response [200]>
# http-wikipedia-org-cite-ref-7-17-0 html
# <Response [200]>
# http-wikipedia-org-cite-ref-7-17-1 html
# <Response [200]>
# http-wikipedia-org-cite-ref-18 html
# <Response [200]>
# http-wikipedia-org-cite-ref-19 html
# <Response [200]>
# http-wikipedia-org-wiki-special-booksources-0-12-241770-4 html
# <Response [200]>
# http-wikipedia-org-wiki-oclc-identifier html
# <Response [404]>
# http-wikipedia-org-www-worldcat-org-oclc-489990740 html
# <Response [200]>
# http-wikipedia-org-wiki-category-cs1-maint-others html
# <Response [200]>
# http-wikipedia-org-cite-ref-murtagh-2018-14-20-0 html
# <Response [200]>
# http-wikipedia-org-cite-ref-murtagh-2018-14-20-1 html
# <Response [200]>
# http-wikipedia-org-cite-ref-0-21-0 html
# <Response [200]>
# http-wikipedia-org-cite-ref-0-21-1 html
# <Response [200]>
# http-wikipedia-org-cite-ref-0-21-2 html
# <Response [200]>
# http-wikipedia-org-cite-ref-22 html
# <Response [200]>
# http-wikipedia-org-cite-ref-1-23-0 html
# <Response [200]>
# http-wikipedia-org-cite-ref-1-23-1 html
# <Response [200]>
# http-wikipedia-org-cite-ref-1-23-2 html
# <Response [200]>
# http-wikipedia-org-cite-ref-24 html
# <Response [200]>
# http-wikipedia-org-cite-ref-25 html
# <Response [200]>
# http-wikipedia-org-cite-ref-26 html
# <Response [404]>
# http-wikipedia-org-www-worldcat-org-issn-0017-8012 html
# <Response [200]>
# http-wikipedia-org-cite-ref-27 html
# <Response [200]>
# http-wikipedia-org-cite-ref-28 html
# <Response [200]>
# http-wikipedia-org-cite-ref-5-29-0 html
# <Response [200]>
# http-wikipedia-org-cite-ref-6-30-0 html
# <Response [200]>
# http-wikipedia-org-wiki-template-data html
# <Response [200]>
# http-wikipedia-org-wiki-template-talk-data html
# <Response [200]>
# http-wikipedia-org-wiki-data-computing html
# <Response [200]>
# http-wikipedia-org-wiki-data-augmentation html
# <Response [200]>
# http-wikipedia-org-wiki-data-archaeology html
# <Response [200]>
# http-wikipedia-org-wiki-data-cleansing html
# <Response [200]>
# http-wikipedia-org-wiki-data-collection html
# <Response [200]>
# http-wikipedia-org-wiki-data-compression html
# <Response [200]>
# http-wikipedia-org-wiki-data-corruption html
# <Response [200]>
# http-wikipedia-org-wiki-data-curation html
# <Response [200]>
# http-wikipedia-org-wiki-data-degradation html
# <Response [200]>
# http-wikipedia-org-wiki-data-editing html
# <Response [200]>
# http-wikipedia-org-wiki-extract-transform-load html
# <Response [200]>
# http-wikipedia-org-wiki-extract-load-transform html
# <Response [200]>
# http-wikipedia-org-wiki-data-extraction html
# <Response [200]>
# http-wikipedia-org-wiki-data-transformation html
# <Response [200]>
# http-wikipedia-org-wiki-data-loading html
# <Response [200]>
# http-wikipedia-org-wiki-data-farming html
# <Response [200]>
# http-wikipedia-org-wiki-data-format-management html
# <Response [200]>
# http-wikipedia-org-wiki-data-fusion html
# <Response [200]>
# http-wikipedia-org-wiki-data-integration html
# <Response [200]>
# http-wikipedia-org-wiki-data-integrity html
# <Response [200]>
# http-wikipedia-org-wiki-data-library html
# <Response [200]>
# http-wikipedia-org-wiki-data-loss html
# <Response [200]>
# http-wikipedia-org-wiki-data-management html
# <Response [200]>
# http-wikipedia-org-wiki-data-migration html
# <Response [200]>
# http-wikipedia-org-wiki-data-pre-processing html
# <Response [200]>
# http-wikipedia-org-wiki-data-preservation html
# <Response [200]>
# http-wikipedia-org-wiki-information-privacy html
# <Response [200]>
# http-wikipedia-org-wiki-data-recovery html
# <Response [200]>
# http-wikipedia-org-wiki-data-reduction html
# <Response [200]>
# http-wikipedia-org-wiki-data-retention html
# <Response [200]>
# http-wikipedia-org-wiki-data-quality html
# <Response [200]>
# http-wikipedia-org-wiki-data-scraping html
# <Response [200]>
# http-wikipedia-org-wiki-data-scrubbing html
# <Response [200]>
# http-wikipedia-org-wiki-data-security html
# <Response [200]>
# http-wikipedia-org-wiki-data-steward html
# <Response [200]>
# http-wikipedia-org-wiki-data-storage html
# <Response [200]>
# http-wikipedia-org-wiki-data-validation html
# <Response [200]>
# http-wikipedia-org-wiki-data-warehouse html
# <Response [200]>
# http-wikipedia-org-wiki-data-wrangling html
# <Response [200]>
# http-wikipedia-org-wiki-help-category html
# <Response [200]>
# http-wikipedia-org-wiki-category-information-science html
# <Response [200]>
# http-wikipedia-org-wiki-category-computer-occupations html
# <Response [200]>
# http-wikipedia-org-wiki-category-computational-fields-of-study html
# <Response [200]>
# http-wikipedia-org-wiki-category-data-analysis html
# <Response [200]>
# http-wikipedia-org-wiki-category-articles-with-short-description html
# <Response [200]>
# http-wikipedia-org-wiki-category-short-description-matches-wikidata html
# <Response [200]>
# http-wikipedia-org-wiki-category-use-dmy-dates-from-august-2021 html
# <Response [200]>
# http-wikipedia-org-wiki-special-mytalk html
# <Response [200]>
# http-wikipedia-org-wiki-special-mycontributions html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-special-createaccount-returnto-data-science html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-special-userlogin-returnto-data-science html
# <Response [200]>
# http-wikipedia-org-wiki-data-science html
# <Response [200]>
# http-wikipedia-org-wiki-talk-data-science html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-edit html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-history html
# <Response [200]>
# http-wikipedia-org-wiki-main-page html
# <Response [200]>
# http-wikipedia-org-wiki-wikipedia-contents html
# <Response [200]>
# http-wikipedia-org-wiki-portal-current-events html
# <Response [200]>
# http-wikipedia-org-wiki-special-random html
# <Response [200]>
# http-wikipedia-org-wiki-wikipedia-about html
# <Response [404]>
# http-wikipedia-org-en-wikipedia-org-wiki-wikipedia-contact-us html
# <Response [200]>
# http-wikipedia-org-wiki-help-contents html
# <Response [200]>
# http-wikipedia-org-wiki-help-introduction html
# <Response [200]>
# http-wikipedia-org-wiki-wikipedia-community-portal html
# <Response [200]>
# http-wikipedia-org-wiki-special-recentchanges html
# <Response [200]>
# http-wikipedia-org-wiki-wikipedia-file-upload-wizard html
# <Response [200]>
# http-wikipedia-org-wiki-special-whatlinkshere-data-science html
# <Response [200]>
# http-wikipedia-org-wiki-special-recentchangeslinked-data-science html
# <Response [200]>
# http-wikipedia-org-wiki-special-specialpages html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-oldid-1063001066 html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-action-info html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-special-citethispage-page-data-science-id-1063001066-wpformidentifier-titleform html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-special-downloadaspdf-page-data-science-action-show-download-screen html
# <Response [200]>
# http-wikipedia-org-w-index-php-title-data-science-printable-yes html
# <Response [404]>
# http-wikipedia-org-en-wikipedia-org-wiki-wikipedia-text-of-creative-commons-attribution-sharealike-3-0-unported-license html
# <Response [404]>
# http-wikipedia-org-creativecommons-org-licenses-by-sa-3-0 html
# <Response [404]>
# http-wikipedia-org-foundation-wikimedia-org-wiki-terms-of-use html
# <Response [404]>
# http-wikipedia-org-foundation-wikimedia-org-wiki-privacy-policy html
# <Response [404]>
# http-wikipedia-org-www-wikimediafoundation-org html
# <Response [200]>
# http-wikipedia-org-wiki-wikipedia-general-disclaimer html
# <Response [404]>
# http-wikipedia-org-en-m-wikipedia-org-w-index-php-title-data-science-mobileaction-toggle-view-mobile html
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Wall time: 2min 12s

# %% [markdown]
# ### Step 7: Perform the page indexing in parallel and note the difference in performance.
# Remember to include %%time at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
import multiprocessing

# %%
# %%time

pool = multiprocessing.Pool()
result = pool.map(index_page, all_links)
pool.terminate()
pool.join()
print(result)
