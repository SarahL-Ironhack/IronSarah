# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp = pd.read_csv(r'C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_2\Lab_10_Subsetting_and_Descriptive_Statistics\Temp_states.csv')

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
City and State are both object, although they could (should?) be string, temperature is float which is ok
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
ny = temp[temp['State']=='New York']

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
ny['Temperature'].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
fifteen = temp[temp['Temperature']>15]
fifteen
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
fifteen['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp.loc[(temp['Temperature']>15) & (temp['Temperature']< 20),['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
temp.groupby('State', as_index=False).agg(['mean', 'std'])
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv(r'C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_2\Lab_10_Subsetting_and_Descriptive_Statistics\employees.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
all string columns are saved as objects, numerical are int
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employees
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %%
# your code here
employees[employees['Salary']==employees['Salary'].min()]
# Out:
#     Department Education      Title      Name  Years  Salary
# 27          IT  Bachelor    Analyst      Sean     12      30
# 106      Admin  Bachelor  associate      Luke      4      30
# 128      Sales       PhD         VP      Adam      8      30
# 139      Sales       PhD    Analyst      Rick     11      30
# 214      Sales    Master         VP      Neil     11      30
# 266         HR       PhD  associate    Marcel     10      30
# 452         IT  Bachelor    Analyst  Augustin     13      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees[employees['Name']=='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees.loc[employees['Name']=="David"]['Salary']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
assoc = employees[employees['Title']=='associate']
assoc
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
assoc.iloc[:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
# your code here
assoc.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees[(employees['Title']=="associate")&(employees['Salary']>55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby('Years', as_index=False).agg('mean')
# Out:
#     Years     Salary
# 0       1  75.863636
# 1       2  75.857143
# 2       3  74.571429
# 3       4  77.129032
# 4       5  73.857143
# 5       6  72.382353
# 6       7  73.840000
# 7       8  64.250000
# 8       9  76.741935
# 9      10  73.351351
# 10     11  74.866667
# 11     12  73.454545
# 12     13  71.935484
# 13     14  70.968750
# 14     15  69.758621

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees[['Title','Salary']].groupby('Title', as_index=False).agg('mean')
# Out:
#        Title     Salary
# 0    Analyst  73.703911
# 1         VP  72.907975
# 2  associate  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
employees['test']=''
employees['test']=np.where(employees['Department']=="Admin",'True', 'False')
employees
# Out:
#     Department Education      Title       Name  Years  Salary   test
# 106      Admin  Bachelor  associate       Luke      4      30   True
# 214      Sales    Master         VP       Neil     11      30  False
# 27          IT  Bachelor    Analyst       Sean     12      30  False
# 128      Sales       PhD         VP       Adam      8      30  False
# 139      Sales       PhD    Analyst       Rick     11      30  False
# 266         HR       PhD  associate     Marcel     10      30  False
# 452         IT  Bachelor    Analyst   Augustin     13      30  False
# 333         IT    Master    Analyst     Edward      5      31  False
# 243         HR       PhD  associate       Chad      5      31  False
# 47       Admin  Bachelor         VP    Melissa      8      31   True
# 124         IT  Bachelor         VP      David      3      31  False
# 374         HR       PhD    Analyst      Nancy      7      31  False
# 458      Sales       PhD  associate    Heather      3      31  False
# ...

# %%
# your code here
employees.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
pd.set_option('display.max_rows', 500)

# %%
# your code here
employees.pivot_table(index=['Years','Name'],columns=['Department','Title'], fill_value=0)
# no clear indication on the gender expect for the name
# here we can see the average salary per person and years of experience, considering their department and title
# Out:
#                  Salary                                                     \
# Department        Admin                     HR                     IT
# Title           Analyst   VP associate Analyst   VP associate Analyst   VP
# Years Name
# 1     Alice         102    0         0       0   70         0       0    0
#       Ann             0    0         0       0    0         0      32    0
#       Calvin          0    0         0       0    0         0       0    0
#       Carol           0  114         0       0    0         0       0    0
#       Chelsea         0    0         0       0   72         0       0    0
#       Cynthia         0    0       114       0    0         0       0    0
#       Daniel          0    0         0       0    0         0       0    0
#       Darrell         0    0         0       0    0       117       0    0
#       Don           120    0         0       0    0         0       0    0
# ...

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
deps = employees[['Department','Years','Salary']].groupby('Department', as_index=False).agg(['min','mean','max'])
deps
# Out:
#            Years               Salary
#              min      mean max    min       mean  max
# Department
# Admin          1  7.642276  15     30  76.325203  120
# HR             1  7.172131  15     30  74.237705  119
# IT             1  8.141791  15     30  70.671642  120
# Sales          1  7.206612  15     30  73.132231  120

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
employees.groupby('Department').apply(lambda row: row['Salary'].max() - row['Salary'].min())

employees.groupby('Department').agg({'Salary' : lambda row: row.max() - row.min()})
# Out:
#             Salary
# Department
# Admin           90
# HR              89
# IT              90
# Sales           90

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_csv(r'C:\Users\Sarah\Downloads\Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6   2010-12-01 8:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
"""
We have a lot of numerical data and a couple columns with categorical data
There seem to be outliers or errors on quantity, amount_spent, unit price
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
orders['amount_spent'].mean()
# Out:
# 22.39474850474768

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 8:26:00
# 1                  white metal lantern         6  2010-12-01 8:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 8:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 8:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 8:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
# your code here
a =orders[orders['Country']=='Spain']
spanish = a.groupby('CustomerID').nunique()
spanish
# Out:
#             Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# CustomerID
# 12354               58          1         58     1      1    1     1
# 12417               23          1         23     1      1    1     1
# 12421               45          4         32     1      4    4     4
# 12442               12          1         12     1      1    1     1
# 12445                4          1          4     1      1    1     1
# 12448               22          1         22     1      1    1     1
# 12450                8          2          7     1      2    2     1
# 12454               15          1         15     1      1    1     1
# 12455               48          4         44     1      4    4     3
# 12462               62          2         51     1      2    2     2
# 12484              346          6        256     1      4    5     5
# 12502              147          5        102     1      5    4     5
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
spanish.count()
# Out:
# Unnamed: 0      30
# InvoiceNo       30
# StockCode       30
# year            30
# month           30
# day             30
# hour            30
# Description     30
# Quantity        30
# InvoiceDate     30
# UnitPrice       30
# Country         30
# amount_spent    30
# dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
fifty =orders.groupby('CustomerID', as_index=False).agg({'Quantity':'sum'})
fifty[fifty['Quantity']>50]
# Out:
#       CustomerID  Quantity
# 0          12346     74215
# 1          12347      2458
# 2          12348      2341
# 3          12349       631
# 4          12350       197
# ...          ...       ...
# 4333       18278        66
# 4335       18281        54
# 4336       18282       103
# 4337       18283      1397
# 4338       18287      1586
#
# [4091 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
span_fifty = orders.groupby(['Country','CustomerID'], as_index=False).agg({'Quantity':'sum'})
span_fifty[(span_fifty['Quantity']>50)&(span_fifty['Country']=='Spain')]
# Out:
#     Country  CustomerID  Quantity
# 357   Spain       12354       530
# 358   Spain       12417       267
# 359   Spain       12421       484
# 360   Spain       12442       182
# 361   Spain       12445        62
# 362   Spain       12448       243
# 363   Spain       12450       128
# 364   Spain       12454      1006
# 365   Spain       12455       566
# 366   Spain       12462       536
# 367   Spain       12484      2191
# 368   Spain       12502       820
# 369   Spain       12507       905
# 370   Spain       12510       353
# 371   Spain       12538       191
# 372   Spain       12539      2067
# 373   Spain       12540      6685
# 374   Spain       12541       680
# 375   Spain       12544       136
# 376   Spain       12545       523
# 377   Spain       12546       633
# 378   Spain       12547       134
# 380   Spain       12550       569
# 381   Spain       12551       100
# 382   Spain       12556       358
# 383   Spain       12557      4384
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
orders[orders['amount_spent']==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
lunchbag =orders[orders['Description'].str.startswith("lunch bag")]
lunchbag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10   2010-12-01 9:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
lunchbag[lunchbag['year']==2011]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
spainfreq = orders[orders['Country']=='Spain'].value_counts('amount_spent').sort_values(ascending = False)
spainfreq
# Out:
# amount_spent
# 15.00      186
# 17.70      122
# 19.80       99
# 17.40       86
# 10.20       76
# 30.00       59
# 16.50       56
# 14.85       56
# 12.60       50
# 10.50       43
# 13.20       41
# 5.04        39
# 9.90        38
# 17.00       35
# 15.30       34
# 15.90       33
# 23.40       31
# 19.90       28
# 20.40       24
# 12.50       24
# 12.75       24
# 25.50       23
# 7.80        22
# 10.08       21
# 16.95       20
# 7.50        20
# 8.50        20
# 3.75        19
# 5.90        19
# 4.95        18
# 19.50       17
# 16.60       17
# 17.85       17
# 2.95        17
# 3.30        17
# 25.20       16
# 39.60       16
# 9.95        16
# 2.50        16
# 5.10        15
# 1.25        15
# 28.00       15
# 22.50       15
# 2.55        15
# 9.96        15
# 84.00       14
# 29.70       13
# 6.60        13
# 4.68        12
# 20.80       12
# 35.40       12
# 24.96       12
# 13.50       12
# 1.65        11
# 56.00       11
# 2.08        11
# 15.60       11
# ...

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
spainfreq = pd.DataFrame(spainfreq)
spainfreq
# Out:
#                 0
# amount_spent
# 15.00         186
# 17.70         122
# 19.80          99
# 17.40          86
# 10.20          76
# 30.00          59
# 16.50          56
# 14.85          56
# 12.60          50
# 10.50          43
# 13.20          41
# 5.04           39
# 9.90           38
# 17.00          35
# 15.30          34
# 15.90          33
# 23.40          31
# 19.90          28
# 20.40          24
# 12.50          24
# 12.75          24
# 25.50          23
# 7.80           22
# 10.08          21
# 16.95          20
# 7.50           20
# 8.50           20
# 3.75           19
# 5.90           19
# 4.95           18
# 19.50          17
# 16.60          17
# 17.85          17
# 2.95           17
# 3.30           17
# 25.20          16
# 39.60          16
# 9.95           16
# 2.50           16
# 5.10           15
# 1.25           15
# 28.00          15
# 22.50          15
# 2.55           15
# 9.96           15
# 84.00          14
# 29.70          13
# 6.60           13
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6   2010-12-01 8:26:00
# ...

# %%
# your code here
orders[orders['month']==8].groupby('Country').agg({'InvoiceNo':'count'})
# Out:
#                  InvoiceNo
# Country
# Australia              107
# Austria                 88
# Belgium                194
# Canada                   5
# Channel Islands        140
# Denmark                 16
# EIRE                   593
# Finland                 61
# France                 569
# Germany                795
# Iceland                 22
# Israel                 171
# Italy                   95
# Malta                   55
# Netherlands            280
# Norway                  77
# Poland                  17
# Portugal                41
# Spain                  252
# Sweden                  40
# Switzerland            267
# United Kingdom       23105
# Unspecified             23

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.groupby('Country').agg({'amount_spent':'mean'})
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders[orders['UnitPrice']==orders['UnitPrice'].max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.groupby('year').agg({'amount_spent':'mean'})
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
