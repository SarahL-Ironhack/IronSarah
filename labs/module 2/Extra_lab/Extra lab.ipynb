# %% [markdown]
# # Interactive Visualization Lab
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd;
import plotly.offline as py;
from plotly import tools;
import plotly.graph_objs as go;
import warnings;
from ipywidgets import interact;
import plotly.express as px

warnings.filterwarnings('ignore')
py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_excel(r"C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_2\Extra_Lab\Online Retail.xlsx")

# %%
data
# Out:
#         InvoiceNo         InvoiceDate StockCode  \
# 0          536365 2010-12-01 08:26:00    85123A
# 1          536373 2010-12-01 09:02:00    85123A
# 2          536375 2010-12-01 09:32:00    85123A
# 3          536390 2010-12-01 10:19:00    85123A
# 4          536394 2010-12-01 10:39:00    85123A
# ...           ...                 ...       ...
# 396029     580691 2011-12-05 15:48:00    90214W
# 396030     580691 2011-12-05 15:48:00    90214Z
# 396031     580865 2011-12-06 11:58:00     90089
# 396032     580865 2011-12-06 11:58:00     90089
# 396033     581425 2011-12-08 15:31:00     90089
#
#                                Description  Quantity  UnitPrice  Revenue  \
# 0       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 1       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 2       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3       CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# ...

# %% [markdown]
# #### 1. Create an interactive bar chart showing total quantity and revenue by country (excluding United Kingdom) for the month of April 2011.

# %%
# Transform the data
april =  data[data['InvoiceDate'].dt.month == 4]

total_qty_rvn = april.groupby('Country', as_index=False)['Revenue','Quantity'].sum()
total_qty_rvn = total_qty_rvn[total_qty_rvn['Country']!='United Kingdom']
total_qty_rvn
# Out:
#             Country   Revenue  Quantity
# 0         Australia    421.60       224
# 1           Austria    584.78       308
# 2           Belgium   1788.48      1170
# 3            Brazil   1143.60       356
# 4   Channel Islands    243.00        96
# 5              EIRE   7270.50      4129
# 6           Finland   1368.92       810
# 7            France   3899.31      2265
# 8           Germany  10994.79      5702
# 9            Greece    509.74       260
# 10          Iceland    636.25       483
# 11            Italy    737.83       653
# 12            Japan   6548.50      8058
# 13      Netherlands   2886.56      1762
# 14           Poland    705.84       432
# 15         Portugal   1687.75       951
# 16        Singapore   2118.74      1384
# 17            Spain   1645.65       948
# 18           Sweden    649.10       306
# 19      Switzerland   1756.94       878
# 20              USA    383.95       137

# %%
# Traces
#traces = 

# Layout
#layout = 

# Plot
fig = px.bar(total_qty_rvn, x="Country", y=["Quantity","Revenue"], title="Total quantity and revenue per Country in April")
fig.show()
py.iplot
# Out:
# <div>                            <div id="62cd0ec2-92dd-4b51-b91b-55c0a956bcfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62cd0ec2-92dd-4b51-b91b-55c0a956bcfe")) {                    Plotly.newPlot(                        "62cd0ec2-92dd-4b51-b91b-55c0a956bcfe",                        [{"alignmentgroup":"True","hovertemplate":"variable=Quantity<br>Country=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Quantity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Quantity","offsetgroup":"Quantity","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia","Austria","Belgium","Brazil","Channel Islands","EIRE","Finland","France","Germany","Greece","Iceland","Italy","Japan","Netherlands","Poland","Portugal","Singapore","S
# ...

# %% [markdown]
# #### 2. Create an interactive line chart showing quantity and revenue sold to France between January 1st and May 31st 2011.

# %%
data.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
# Transform the data
france_5m_2011 = data[data['Country']=='France']

start_date = "2011-1-1"
end_date = "2011-5-31"

after_start_date = france_5m_2011["InvoiceDate"] >= start_date
before_end_date = france_5m_2011["InvoiceDate"] <= end_date

between_two_dates = after_start_date & before_end_date

france_5m_2011 = france_5m_2011.loc[between_two_dates]
france_5m_2011 = france_5m_2011.groupby('InvoiceDate', as_index=False)['Quantity','Revenue'].sum()

# %%
# Traces
#traces = 
# Layout
#layout = 

# Plot
fig = px.line(france_5m_2011, x="InvoiceDate", y=["Quantity","Revenue"], title="Total quantity and revenue sold to France between January and May 2011")
fig.show()
# Out:
# <div>                            <div id="4838c668-7d70-43b6-b039-85f59d916b5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4838c668-7d70-43b6-b039-85f59d916b5a")) {                    Plotly.newPlot(                        "4838c668-7d70-43b6-b039-85f59d916b5a",                        [{"hovertemplate":"variable=Quantity<br>InvoiceDate=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Quantity","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Quantity","orientation":"v","showlegend":true,"x":["2011-01-05T12:42:00","2011-01-05T14:48:00","2011-01-06T14:26:00","2011-01-06T16:12:00","2011-01-07T12:07:00","2011-01-07T13:13:00","2011-01-09T12:46:00","2011-01-10T13:22:00","2011-01-11T07:57:00","2011-01-11T1
# ...

# %% [markdown]
# #### 3. Create an interactive scatter plot showing the relationship between average quantity (x-axis) and average unit price (y-axis) for the product PARTY BUNTING with the plot points color-coded by country (categories).

# %%
data['Description'].value_counts()
# Out:
# CREAM HANGING HEART T-LIGHT HOLDER     2035
# REGENCY CAKESTAND 3 TIER               1721
# JUMBO BAG RED RETROSPOT                1618
# ASSORTED COLOUR BIRD ORNAMENT          1405
# PARTY BUNTING                          1396
#                                        ...
# FLAG OF ST GEORGE CAR FLAG                1
# BLUE/GREEN SHELL NECKLACE W PENDANT       1
# SET 10 CARDS HANGING BAUBLES 17080        1
# OCEAN STRIPE HAMMOCK                      1
# FIRE POLISHED GLASS BRACELET BLACK        1
# Name: Description, Length: 3640, dtype: int64

# %%
# Transform the data
party_bunting = data[data['Description']=='PARTY BUNTING']

pb_country_qty_up = party_bunting.groupby('Country', as_index=False)['Quantity','UnitPrice'].mean()
pb_country_qty_up
# Out:
#             Country   Quantity  UnitPrice
# 0         Australia  33.125000   4.712500
# 1           Austria   8.000000   4.950000
# 2           Belgium   4.000000   4.950000
# 3   Channel Islands  13.333333   4.950000
# 4            Cyprus   2.333333   4.750000
# 5           Denmark  12.000000   4.950000
# 6              EIRE  21.210526   4.739474
# 7           Finland   6.000000   4.950000
# 8            France   5.727273   4.922727
# 9           Germany   6.800000   4.890000
# 10           Israel   1.000000   4.950000
# 11            Japan  56.666667   4.183333
# 12          Lebanon  15.000000   4.650000
# 13      Netherlands  50.000000   4.150000
# 14           Norway   6.000000   4.950000
# 15        Singapore   8.000000   4.950000
# 16     South Africa   4.000000   4.950000
# 17            Spain   4.750000   4.837500
# 18      Switzerland  17.200000   4.790000
# 19   United Kingdom  10.705432   4.880926

# %%
# Traces
traces = px.scatter(pb_country_qty_up , x="Quantity", y=['UnitPrice'],color="Country")

# Layout 
layout = go.Layout(width=700, height=600,
                   xaxis=go.layout.XAxis(title=go.layout.xaxis.Title(text='Average Quantity')),
                   yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Average Unit Price')),
                   title=go.layout.Title(text='Average Quantity VS Average Unit Price'));
# Plot
py.iplot(go.Figure(data=traces, layout=layout));
# Out:
# <div>                            <div id="224e7865-bb18-42f3-b5e2-9432bdd98088" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("224e7865-bb18-42f3-b5e2-9432bdd98088")) {                    Plotly.newPlot(                        "224e7865-bb18-42f3-b5e2-9432bdd98088",                        [{"hovertemplate":"Country=Australia<br>Quantity=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[33.125],"xaxis":"x","y":[4.7125],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Austria<br>Quantity=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Austria","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","n
# ...

# %% [markdown]
# #### 4. Create a set of interactive histograms showing the distributions of quantity per invoice for the following countries: EIRE, Germany, France, and Netherlands.

# %%
countries
# Out:
#         InvoiceNo         InvoiceDate StockCode  \
# 179        539320 2010-12-16 19:16:00    85123A
# 198        539722 2010-12-21 13:45:00    85123A
# 304        541570 2011-01-19 12:34:00    85123A
# 322        541979 2011-01-24 14:54:00    85123A
# 367        542777 2011-02-01 08:31:00    85123A
# ...           ...                 ...       ...
# 396001     581001 2011-12-07 08:07:00     23562
# 396005     581175 2011-12-07 15:16:00     23562
# 396007     581266 2011-12-08 11:25:00     23562
# 396021     581175 2011-12-07 15:16:00     23561
# 396022     581266 2011-12-08 11:25:00     23561
#
#                                 Description  Quantity  UnitPrice  Revenue  \
# 179      CREAM HANGING HEART T-LIGHT HOLDER        24       2.95    70.80
# 198      CREAM HANGING HEART T-LIGHT HOLDER        24       2.95    70.80
# 304      CREAM HANGING HEART T-LIGHT HOLDER       256       2.55   652.80
# 322      CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
# ...

# %%
# Transform the data
EIRE = data[data['Country']=='EIRE']
Germany= data[data['Country']=='Germany']
France = data[data['Country']=='France']
Netherlands = data[data['Country']=='Netherlands']
#qty_invc = countries.groupby(['Country','InvoiceNo'],as_index=False)['Quantity'].sum()
EIRE = EIRE.groupby('InvoiceNo', as_index=False)['Quantity'].sum()
Germany = Germany.groupby('InvoiceNo', as_index=False)['Quantity'].sum()
France = France.groupby('InvoiceNo', as_index=False)['Quantity'].sum()
Netherlands = Netherlands.groupby('InvoiceNo', as_index=False)['Quantity'].sum()
France
# Out:
#      InvoiceNo  Quantity
# 0       536370       446
# 1       536852       106
# 2       536974       130
# 3       537065       602
# 4       537463       581
# ..         ...       ...
# 374     580986       250
# 375     581001       309
# 376     581171       247
# 377     581279        18
# 378     581587       105
#
# [379 rows x 2 columns]

# %%
# Traces
from plotly.subplots import make_subplots
import plotly.graph_objects as go
trace0= France
#trace1= qty_invc[qty_invc['Country']=='Germany']
#trace2= qty_invc[qty_invc['Country']=='France']
#trace3= qty_invc[qty_invc['Country']=='Netherlands']

# Subplots
fig = px.histogram(countries, x="InvoiceNo", color="Country")


# Layout
#fig['layout'].update(width=1000, height=600, title='Histogram (Quantity per Invoice)')

# Plot
py.iplot(fig);
# Out:
# <div>                            <div id="99426c97-f6fc-4eab-aede-cf27fc37bf2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99426c97-f6fc-4eab-aede-cf27fc37bf2d")) {                    Plotly.newPlot(                        "99426c97-f6fc-4eab-aede-cf27fc37bf2d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=EIRE<br>InvoiceNo=%{x}<br>count=%{y}<extra></extra>","legendgroup":"EIRE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"EIRE","offsetgroup":"EIRE","orientation":"v","showlegend":true,"x":[539320,539722,541979,542777,543114,544210,544690,545657,546580,549667,551656,552262,553203,554770,555947,560036,561798,562935,563169,565748,565800,565857,566625,567378,570016,570674,571314,571425,5724
# ...

# %% [markdown]
# #### 5. Create an interactive side-by-side bar chart showing the revenue by country listed below (bars) for each of the products listed below.

# %%
# Variables
product_list = ['JUMBO BAG RED RETROSPOT', 
                'CREAM HANGING HEART T-LIGHT HOLDER',
                'REGENCY CAKESTAND 3 TIER']

country_list = ['EIRE', 'Germany', 'France', 'Netherlands']

# %%
# Transform the data
rvn_country = data[data['Country'].isin(country_list) &
                   data['Description'].isin(product_list)]
rvn_country = rvn_country.pivot_table(index='Country', columns='Description', values='Revenue', aggfunc='sum');

# %%
rvn_country
# Out:
# Description  CREAM HANGING HEART T-LIGHT HOLDER  JUMBO BAG RED RETROSPOT  \
# Country
# EIRE                                    2740.80                   278.72
# France                                   131.75                   903.37
# Germany                                   35.40                  1072.76
# Netherlands                             1167.00                  3468.00
#
# Description  REGENCY CAKESTAND 3 TIER
# Country
# EIRE                          7388.55
# France                        2816.85
# Germany                       9061.95
# Netherlands                   3166.35

# %% [markdown]
# ##### df

# %%
# Traces
trace0 = go.Bar(x=rvn_country.index, y=rvn_country["CREAM HANGING HEART T-LIGHT HOLDER"],
                name='CREAM HANGING HEART T-LIGHT HOLDER')
trace1 = go.Bar(x=rvn_country.index, y=rvn_country["JUMBO BAG RED RETROSPOT"], 
                name = 'JUMBO BAG RED RETROSPOT')
trace2 = go.Bar(x=rvn_country.index, y=rvn_country["REGENCY CAKESTAND 3 TIER"], 
                name ="REGENCY CAKESTAND 3 TIER" )
# Layout
layout = go.Layout(title ='Products quantity per country')

traces = [trace0, trace1, trace2]
# Plot
py.iplot(go.Figure(data=traces, layout=layout));
# Out:
# <div>                            <div id="62b59398-fb64-42bd-b783-971a7bb8db71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62b59398-fb64-42bd-b783-971a7bb8db71")) {                    Plotly.newPlot(                        "62b59398-fb64-42bd-b783-971a7bb8db71",                        [{"name":"CREAM HANGING HEART T-LIGHT HOLDER","x":["EIRE","France","Germany","Netherlands"],"y":[2740.8,131.75,35.40000000000001,1167.0],"type":"bar"},{"name":"JUMBO BAG RED RETROSPOT","x":["EIRE","France","Germany","Netherlands"],"y":[278.72,903.37,1072.76,3468.0],"type":"bar"},{"name":"REGENCY CAKESTAND 3 TIER","x":["EIRE","France","Germany","Netherlands"],"y":[7388.55,2816.85,9061.949999999999,3166.35],"type":"bar"}],                        {"template":{"data":
# ...

# %% [markdown]
# #### 6. Create an interactive line chart showing quantity sold by day for the United Kingdom. Add drop-down boxes for Year and Month that allow you to filter the date range that appears in the chart.

# %%
# Transform the data
data['Year'] = pd.DatetimeIndex(data['InvoiceDate']).year;
data['Month'] = pd.DatetimeIndex(data['InvoiceDate']).month;
data['Day'] = pd.DatetimeIndex(data['InvoiceDate']).day;
uk = data[data['Country']=='United Kingdom'];

# %%
# Variables
years = uk['Year'].unique();
months = uk['Month'].unique();
months.sort();

# %%
uk
# Out:
#         InvoiceNo         InvoiceDate StockCode  \
# 0          536365 2010-12-01 08:26:00    85123A
# 1          536373 2010-12-01 09:02:00    85123A
# 2          536375 2010-12-01 09:32:00    85123A
# 3          536390 2010-12-01 10:19:00    85123A
# 4          536394 2010-12-01 10:39:00    85123A
# ...           ...                 ...       ...
# 396029     580691 2011-12-05 15:48:00    90214W
# 396030     580691 2011-12-05 15:48:00    90214Z
# 396031     580865 2011-12-06 11:58:00     90089
# 396032     580865 2011-12-06 11:58:00     90089
# 396033     581425 2011-12-08 15:31:00     90089
#
#                                Description  Quantity  UnitPrice  Revenue  \
# 0       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 1       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 2       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3       CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# ...

# %%
# Interactive menu
@interact(year=years, 
          month=months)

# Update function
def linechart(year=2011, month=4):
    # Transform the data
    data1 = uk[(uk['InvoiceDate'].dt.year == year)&(uk['InvoiceDate'].dt.month == month)]
    data1 = data1.groupby([pd.Grouper(key='InvoiceDate',freq='D')])['Quantity'].sum()
    data1 = data1.to_frame()
    # Traces
    trace0 = go.Line(x=data1.index, y=data1['Quantity'])
    traces = [trace0]
    # Layout
    layout = go.Layout(title ='Total quantity sold in UK')
    # Plot
    py.iplot(go.Figure(data=traces, layout=layout));
# Out:
# interactive(children=(Dropdown(description='year', index=1, options=(2010, 2011), value=2011), Dropdown(descri…

# %% [markdown]
# #### 7. Create an interactive scatter plot that plots number of invoices (x-axis) vs. number of customers (y-axis) and the plot points represent individual products. Add two sliders that control the x and y axis ranges.

# %%
x = data[]
# Out:
#         InvoiceNo         InvoiceDate StockCode  \
# 0          536365 2010-12-01 08:26:00    85123A
# 1          536373 2010-12-01 09:02:00    85123A
# 2          536375 2010-12-01 09:32:00    85123A
# 3          536390 2010-12-01 10:19:00    85123A
# 4          536394 2010-12-01 10:39:00    85123A
# ...           ...                 ...       ...
# 396029     580691 2011-12-05 15:48:00    90214W
# 396030     580691 2011-12-05 15:48:00    90214Z
# 396031     580865 2011-12-06 11:58:00     90089
# 396032     580865 2011-12-06 11:58:00     90089
# 396033     581425 2011-12-08 15:31:00     90089
#
#                                Description  Quantity  UnitPrice  Revenue  \
# 0       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 1       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 2       CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3       CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# ...

# %%
# Transform the data
agg_func = {'InvoiceNo':'nunique',
            'Quantity':'sum',
            'UnitPrice':'mean',
            'Revenue':'sum',
            'CustomerID':'nunique'}

products = data['Description'].unique()
products
# Out:
# array(['CREAM HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'LETTER "W" BLING KEY RING',
#        'LETTER "Z" BLING KEY RING', 'PINK CRYSTAL SKULL PHONE CHARM'],
#       dtype=object)

# %%
data3 = data.groupby(['Description']).agg(agg_func)
data3
# Out:
#                                   InvoiceNo  Quantity  UnitPrice  Revenue  \
# Description
#  4 PURPLE FLOCK DINNER CANDLES           36       140   2.324359   270.76
#  50'S CHRISTMAS GIFT BAG LARGE          111      1909   1.248108  2302.25
#  DOLLY GIRL BEAKER                      133      2398   1.243841  2759.50
#  I LOVE LONDON MINI BACKPACK             69       361   4.138732  1458.15
#  NINE DRAWER OFFICE TIDY                 30        55  14.791935   792.85
# ...                                     ...       ...        ...      ...
# ZINC T-LIGHT HOLDER STARS SMALL         237      4894   0.836975  3879.98
# ZINC TOP  2 DOOR WOODEN SHELF             9        10  16.950000   169.50
# ZINC WILLIE WINKIE  CANDLE STICK        188      2607   0.872344  2176.95
# ZINC WIRE KITCHEN ORGANISER              12        25   7.175000   156.80
# ZINC WIRE SWEETHEART LETTER TRAY         20        80   3.454000   253.24
#
#                                   CustomerID
# Description
# ...

# %%
# Interactive menu
#@interact(invoices=(products['InvoiceNo'].min(), products['InvoiceNo'].max(), 10), 
 #         customers=(products['CustomerID'].min(), products['CustomerID'].max(), 10))

# Update function
def scatter(invoices=1, customers=1):
    # Transform the data
    data3 = data.groupby(['Description']).agg(agg_func)
    # Traces
    trace0 = go.Scatter(x=data3[data3['InvoiceNo']==invoices], y=data3[data3['CustomerId']==customers])
    traces = [trace0]
    # Layout 
    layout = go.Layout(title ='Total quantity sold in UK')
    # Plot
    py.iplot(go.Figure(data=traces, layout=layout));

# %% [markdown]
# #### 8. Create an interactive bar chart that shows revenue by product description. Add a text field widget that filters the results to show the product that contain the text entered in their description.

# %%
data.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
# Interactive menu
@interact(product='')

# Update function
def chart(product):
    # Transform the data
    transformed=data[data['Description']==product]
    transformed=transformed[['Description',"Revenue"]].groupby('Description',as_index=False).agg('sum')
    fig = px.bar(transformed, x="Description", y="Revenue", title="Revenue by product description")
    fig.show()
# Out:
# interactive(children=(Text(value='', description='product'), Output()), _dom_classes=('widget-interact',))
