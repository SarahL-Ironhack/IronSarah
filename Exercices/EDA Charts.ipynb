# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\Sarah\Downloads\vehicles.csv')

# %%
data.boxplot(column="Combined MPG", figsize = (8,6))
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(x="Fuel Type", y="Highway MPG", data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# find outliers ont 1,2,4,7 (black spots)
# issues also with mean that is sometimes close to end
# Out:
# [Text(0, 0, 'Regular'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Diesel'),
#  Text(3, 0, 'Premium and Electricity'),
#  Text(4, 0, 'Premium or E85'),
#  Text(5, 0, 'Premium Gas or Electricity'),
#  Text(6, 0, 'Gasoline or E85'),
#  Text(7, 0, 'Gasoline or natural gas'),
#  Text(8, 0, 'CNG'),
#  Text(9, 0, 'Regular Gas or Electricity'),
#  Text(10, 0, 'Midgrade'),
#  Text(11, 0, 'Regular Gas and Electricity'),
#  Text(12, 0, 'Gasoline or propane')]

# %%
sns.violinplot("Combined MPG", data=data)
#white spot is mean, black is boxplot and the rest is the distribution
# Out:
# C:\Users\Sarah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG'>
