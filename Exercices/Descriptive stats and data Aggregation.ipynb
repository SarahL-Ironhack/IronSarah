# %%
import numpy as np
import pandas as pd

# %%
animals = pd.read_csv(r'C:\Users\Sarah\Downloads\animals.csv')

# %%
animals.dtypes
# Out:
# brainwt    float64
# bodywt     float64
# animal      object
# dtype: object

# %%
animals.describe()
# Out:
#            brainwt       bodywt
# count    62.000000    62.000000
# mean    198.794290   283.135355
# std     899.182313   930.278876
# min       0.005000     0.140000
# 25%       0.600000     4.250000
# 50%       3.342500    17.250000
# 75%      48.201250   165.998250
# max    6654.180000  5711.860000

# %%
animals.max()
# Out:
# brainwt                  6654.18
# bodywt                   5711.86
# animal     Yellow-bellied_marmot
# dtype: object

# %%
animals.min()
# Out:
# brainwt               0.005
# bodywt                 0.14
# animal     African_elephant
# dtype: object

# %%
animals.std()
# Out:
# C:\Users\Sarah\AppData\Local\Temp/ipykernel_23144/665470068.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   animals.std()
# brainwt    899.182313
# bodywt     930.278876
# dtype: float64

# %%
animals.quantile(0.25)
# Out:
# brainwt    0.60
# bodywt     4.25
# Name: 0.25, dtype: float64

# %%
animals.quantile(0.75)
# Out:
# brainwt     48.20125
# bodywt     165.99825
# Name: 0.75, dtype: float64

# %%
import matplotlib
# %matplotlib inline

animals.boxplot()
# Out:
# <AxesSubplot:>

# %%
animals.hist()
# Out:
# array([[<AxesSubplot:title={'center':'brainwt'}>,
#         <AxesSubplot:title={'center':'bodywt'}>]], dtype=object)

# %%
animals.hist(bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'brainwt'}>,
#         <AxesSubplot:title={'center':'bodywt'}>]], dtype=object)

# %%
cars = pd.read_csv(r'C:\Users\Sarah\Downloads\vehicles.csv')
cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
cars.groupby(['Transmission'])['Highway MPG', 'City MPG', 'Combined MPG'].mean()
# Out:
# C:\Users\Sarah\AppData\Local\Temp/ipykernel_23144/460781299.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cars.groupby(['Transmission'])['Highway MPG', 'City MPG', 'Combined MPG'].mean()
#                                   Highway MPG   City MPG  Combined MPG
# Transmission
# Auto (AV)                           40.000000  35.000000     37.000000
# Auto (AV-S6)                        25.000000  22.000000     23.000000
# Auto (AV-S8)                        22.000000  20.000000     21.000000
# Auto(A1)                            37.000000  41.000000     39.000000
# Auto(AM-S6)                         32.978261  24.315217     27.554348
# Auto(AM-S7)                         25.300781  17.746094     20.425781
# Auto(AM-S8)                         32.000000  23.666667     26.666667
# Auto(AM-S9)                         22.000000  21.000000     21.000000
# ...

# %%
cars.groupby(['Fuel Type','Cylinders'])['CO2 Emission Grams/Mile'].median()
# Out:
# Fuel Type                    Cylinders
# CNG                          4.0          253.197321
#                              6.0          417.030882
#                              8.0          568.070913
# Diesel                       4.0          308.484848
#                              5.0          391.538462
#                              6.0          439.000000
#                              8.0          598.823529
#                              10.0         598.823529
# Gasoline or E85              4.0          355.480000
#                              6.0          444.350000
#                              8.0          592.466667
# Gasoline or natural gas      4.0          386.391304
#                              6.0          437.000000
#                              8.0          740.583333
# Gasoline or propane          8.0          666.525000
# Midgrade                     6.0          416.000000
#                              8.0          527.000000
# ...

# %%
cars.groupby(['Fuel Type'])['Combined MPG'].agg(['mean', 'median'])
# Out:
#                                   mean  median
# Fuel Type
# CNG                          18.133333    14.5
# Diesel                       23.488474    21.0
# Gasoline or E85              17.572385    17.0
# Gasoline or natural gas      15.350000    12.0
# Gasoline or propane          13.500000    13.5
# Midgrade                     17.378378    17.0
# Premium                      19.343816    19.0
# Premium Gas or Electricity   31.647059    33.0
# Premium and Electricity      26.300000    25.5
# Premium or E85               20.090909    20.0
# Regular                      20.144698    20.0
# Regular Gas and Electricity  41.937500    38.5
# Regular Gas or Electricity   42.000000    42.0

# %%
cars.pivot_table(index=['Vehicle Class'])
# Out:
#                                     CO2 Emission Grams/Mile   City MPG  \
# Vehicle Class
# Compact Cars                                     396.758088  20.570685
# Large Cars                                       484.391278  16.130310
# Midsize Cars                                     432.861095  18.950775
# Midsize Station Wagons                           432.128533  18.360577
# Midsize-Large Station Wagons                     452.981561  17.590837
# Minicompact Cars                                 443.861984  18.380363
# Minivan - 2WD                                    469.287896  16.679758
# Minivan - 4WD                                    504.595699  15.425532
# Small Pickup Trucks                              450.039261  18.416031
# Small Pickup Trucks 2WD                          454.361734  17.922693
# Small Pickup Trucks 4WD                          497.689565  16.405000
# Small Sport Utility Vehicle 2WD                  378.034759  21.147059
# ...

# %%
 cars.pivot_table(index=['Vehicle Class'], columns = ['Cylinders'])
# Out:
#                                    CO2 Emission Grams/Mile              \
# Cylinders                                             2.0         3.0
# Vehicle Class
# Compact Cars                                           NaN  243.666667
# Large Cars                                             NaN         NaN
# Midsize Cars                                           NaN         NaN
# Midsize Station Wagons                                 NaN         NaN
# Midsize-Large Station Wagons                           NaN         NaN
# Minicompact Cars                                493.722222  234.692515
# Minivan - 2WD                                          NaN         NaN
# Minivan - 4WD                                          NaN         NaN
# Small Pickup Trucks                                    NaN         NaN
# Small Pickup Trucks 2WD                                NaN         NaN
# Small Pickup Trucks 4WD                                NaN         NaN
# ...

# %%
 cars.pivot_table(index=['Vehicle Class'], values = ['Combined MPG'], aggfunc=np.sum)
# Out:
#                                     Combined MPG
# Vehicle Class
# Compact Cars                              121191
# Large Cars                                 32988
# Midsize Cars                               88047
# Midsize Station Wagons                      8746
# Midsize-Large Station Wagons               12612
# Minicompact Cars                           25486
# Minivan - 2WD                               6328
# Minivan - 4WD                                829
# Small Pickup Trucks                        10615
# Small Pickup Trucks 2WD                     8019
# Small Pickup Trucks 4WD                     3625
# Small Sport Utility Vehicle 2WD             8908
# Small Sport Utility Vehicle 4WD            11076
# Small Station Wagons                       32684
# Special Purpose Vehicle                       22
# Special Purpose Vehicle 2WD                10299
# Special Purpose Vehicle 4WD                 4239
# Special Purpose Vehicles                   23525
# ...
