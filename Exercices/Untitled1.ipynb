# %%
import pandas as pd

# %%
call_data = pd.read_csv(r'C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_2\Lab_18_Dasboards_in_Excel_Google_Sheets\Call_data.csv')

# %%
hierarchy = pd.read_csv(r'C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_2\Lab_18_Dasboards_in_Excel_Google_Sheets\Hierarchy.csv')

# %%
targets = pd.read_csv(r'C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_2\Lab_18_Dasboards_in_Excel_Google_Sheets\Targets.csv')

# %%
call_data.head()
# Out:
#     YR_MO   CALL_DATE  AGENT_KEY  CALLS  HANDLE_TIME  CALL_REGEN  \
# 0  201706  2017-06-01      12465     34        25710           5
# 1  201706  2017-06-01      12466     35        25039           4
# 2  201706  2017-06-01      12467     38        24436           6
# 3  201706  2017-06-01      12468     38        24923           5
# 4  201706  2017-06-01      12469     34        24371           4
#
#    CALLS_WITH_OFFER  CALLS_WITH_ACCEPT  CALLS_OFFER_APPLIED  TRANSFERS
# 0                31                 22                   19          2
# 1                34                 29                   26          2
# 2                36                 32                   28          3
# 3                37                 32                   25          2
# 4                32                 25                   22          2

# %%
hierarchy.head()
# Out:
#    AGENT_KEY      EFF_DT     TERM_DT   AGENT_ID         AGENT_NAME  \
# 0      12465  2017-05-01  2020-12-31  201700121   Anderson, Albert
# 1      12466  2017-05-01  2020-12-31  201700122      Binning, Bart
# 2      12467  2017-05-01  2020-12-31  201700123  Centerville, Cece
# 3      12468  2017-05-01  2020-12-31  201700124  Davenport, Davina
# 4      12469  2017-05-01  2020-12-31  201700125    Edgerton, Ethan
#
#    TEAM_LEAD_ID     TEAM_LEAD_NAME  CALL_CENTER
# 0     201700011  Winnerson, Aceona  Williamburg
# 1     201700011  Winnerson, Aceona  Williamburg
# 2     201700011  Winnerson, Aceona  Williamburg
# 3     201700011  Winnerson, Aceona  Williamburg
# 4     201700011  Winnerson, Aceona  Williamburg

# %%
targets.head()
# Out:
#     YR_MO            METRIC   TARGET
# 0  201706               AHT  780.000
# 1  201706        CALL_REGEN    0.167
# 2  201706         TRANSFERS    0.082
# 3  201706  APPLIED_PER_CALL    0.505
# 4  201706          BREAKAGE    0.201

# %%
merged = call_data.merge(hierarchy, on='AGENT_KEY', how='outer')

# %%
merged
# Out:
#        YR_MO   CALL_DATE  AGENT_KEY  CALLS  HANDLE_TIME  CALL_REGEN  \
# 0     201706  2017-06-01      12465     34        25710           5
# 1     201706  2017-06-02      12465     37        24506           4
# 2     201706  2017-06-04      12465     38        25249           5
# 3     201706  2017-06-05      12465     32        24019           3
# 4     201706  2017-06-06      12465     36        24810           6
# ...      ...         ...        ...    ...          ...         ...
# 1520  201708  2017-08-16      12490     32        25345           7
# 1521  201708  2017-08-28      12490     28        24324           8
# 1522  201708  2017-08-29      12490     31        25197           8
# 1523  201708  2017-08-30      12490     33        24633          10
# 1524  201708  2017-08-31      12490     29        24662           6
#
#       CALLS_WITH_OFFER  CALLS_WITH_ACCEPT  CALLS_OFFER_APPLIED  TRANSFERS  \
# 0                   31                 22                   19          2
# ...

# %%
merged.to_excel(r'C:\Users\Sarah\Documents\IronSarah\labs\module 2\lab18\merged.xlsx')

# %%
metrics=pd.read_excel(r'C:\Users\Sarah\Documents\DAFT_NOV_21_01\module_2\Lab_18_Dasboards_in_Excel_Google_Sheets\Metrics.xlsx')

# %%
metrics
# Out:
#                      Metric  \
# 0             Calls Handled
# 1  Avg Handle Time (or AHT)
# 2                Transfer %
# 3                   Offer %
# 4                  Accept %
# 5                 Applied %
# 6                  Breakage
# 7          Applied Per Call
# 8    Callback within 2 Days
#
#                                           Definition  \
# 0                     Inbound call taken by an agent
# 1                    Average time to complete a call
# 2   Percent of calls that resulted in a transfer out
# 3                   Percent of offers made on a call
# 4                  Percent of accepts on offers made
# 5             Percent of applieds on accepted offers
# 6    Percent of calls where an offer was not applied
# 7         Percent of calls that had an applied offer
# 8  Percent of calls where customer called back wi...
#
#                                              Formula
# 0                               Sum of Calls Handled
# ...
