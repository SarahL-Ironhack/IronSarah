# %%
import json
import requests

response = requests.get('https://api.github.com/ta-data-par/DAFT_NOV_21_01')
response.status_code
print(response.status_code)
results = response.json()
# Out:
# 404

# %%
import pandas as pd
data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
response = requests.get('https://api.github.com/events')
data = pd.DataFrame(response.json())
data.head(10)
# Out:
#             id              type  \
# 0  19197514593  PullRequestEvent
# 1  19197514562         PushEvent
# 2  19197514567  PullRequestEvent
# 3  19197514585         ForkEvent
# 4  19197514568         PushEvent
# 5  19197514549         PushEvent
# 6  19197514565         ForkEvent
# 7  19197514552         PushEvent
# 8  19197514494         PushEvent
# 9  19197514528         PushEvent
#
#                                                actor  \
# 0  {'id': 84946696, 'login': 'mikexia930', 'displ...
# 1  {'id': 94089796, 'login': 'npmds', 'display_lo...
# 2  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 3  {'id': 29518524, 'login': 'PluginYML', 'displa...
# 4  {'id': 41898282, 'login': 'github-actions[bot]...
# 5  {'id': 75331162, 'login': 'jonyg80', 'display_...
# 6  {'id': 1597813, 'login': 'Triex', 'display_log...
# 7  {'id': 51066424, 'login': 'MABilton', 'display...
# 8  {'id': 92156529, 'login': 'JupiterD-aurel', 'd...
# 9  {'id': 8517910, 'login': 'LombiqBot', 'display...
#
#                                                 repo  \
# 0  {'id': 423445616, 'name': 'mikexia930/xDatetim...
# 1  {'id': 433661455, 'name': 'npmds/fcms', 'url':...
# 2  {'id': 317622239, 'name': 'FFHixio/nodejs.dev'...
# 3  {'id': 233046875, 'name': 'n3oney/discord.js-t...
# 4  {'id': 371146906, 'name': 'krb2162/flat-demo-b...
# 5  {'id': 432932764, 'name': 'jonyg80/ht-num', 'u...
# 6  {'id': 425881518, 'name': 'vvs-finance/vvs-swa...
# 7  {'id': 429335712, 'name': 'MABilton/arraytaine...
# 8  {'id': 424184805, 'name': 'ElisaDESOUSA/SiteSp...
# 9  {'id': 265094441, 'name': 'Lombiq/UI-Testing-T...
#
#                                              payload  public  \
# 0  {'action': 'opened', 'number': 7, 'pull_reques...    True
# 1  {'push_id': 8549711238, 'size': 1, 'distinct_s...    True
# 2  {'action': 'opened', 'number': 77, 'pull_reque...    True
# 3  {'forkee': {'id': 435457961, 'node_id': 'R_kgD...    True
# 4  {'push_id': 8549711271, 'size': 1, 'distinct_s...    True
# 5  {'push_id': 8549711245, 'size': 1, 'distinct_s...    True
# 6  {'forkee': {'id': 435457960, 'node_id': 'R_kgD...    True
# 7  {'push_id': 8549711259, 'size': 1, 'distinct_s...    True
# 8  {'push_id': 8549711217, 'size': 2, 'distinct_s...    True
# 9  {'push_id': 8549711247, 'size': 0, 'distinct_s...    True
#
#              created_at                                                org
# 0  2021-12-06T10:44:56Z                                                NaN
# 1  2021-12-06T10:44:56Z                                                NaN
# 2  2021-12-06T10:44:56Z  {'id': 74653433, 'login': 'FFHixio', 'gravatar...
# 3  2021-12-06T10:44:56Z                                                NaN
# 4  2021-12-06T10:44:56Z                                                NaN
# 5  2021-12-06T10:44:56Z                                                NaN
# 6  2021-12-06T10:44:56Z  {'id': 91581411, 'login': 'vvs-finance', 'grav...
# 7  2021-12-06T10:44:56Z                                                NaN
# 8  2021-12-06T10:44:56Z                                                NaN
# 9  2021-12-06T10:44:56Z  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)


flat.head(10)
# Out:
#             id              type  public            created_at  actor_id  \
# 0  19197514593  PullRequestEvent    True  2021-12-06T10:44:56Z  84946696
# 1  19197514562         PushEvent    True  2021-12-06T10:44:56Z  94089796
# 2  19197514567  PullRequestEvent    True  2021-12-06T10:44:56Z  49699333
# 3  19197514585         ForkEvent    True  2021-12-06T10:44:56Z  29518524
# 4  19197514568         PushEvent    True  2021-12-06T10:44:56Z  41898282
# 5  19197514549         PushEvent    True  2021-12-06T10:44:56Z  75331162
# 6  19197514565         ForkEvent    True  2021-12-06T10:44:56Z   1597813
# 7  19197514552         PushEvent    True  2021-12-06T10:44:56Z  51066424
# 8  19197514494         PushEvent    True  2021-12-06T10:44:56Z  92156529
# 9  19197514528         PushEvent    True  2021-12-06T10:44:56Z   8517910
#
#            actor_login actor_display_login actor_gravatar_id  \
# 0           mikexia930          mikexia930
# 1                npmds               npmds
# 2      dependabot[bot]          dependabot
# 3            PluginYML           PluginYML
# 4  github-actions[bot]      github-actions
# 5              jonyg80             jonyg80
# 6                Triex               Triex
# 7             MABilton            MABilton
# 8       JupiterD-aurel      JupiterD-aurel
# 9            LombiqBot           LombiqBot
#
#                                           actor_url  \
# 0           https://api.github.com/users/mikexia930
# 1                https://api.github.com/users/npmds
# 2      https://api.github.com/users/dependabot[bot]
# 3            https://api.github.com/users/PluginYML
# 4  https://api.github.com/users/github-actions[bot]
# 5              https://api.github.com/users/jonyg80
# 6                https://api.github.com/users/Triex
# 7             https://api.github.com/users/MABilton
# 8       https://api.github.com/users/JupiterD-aurel
# 9            https://api.github.com/users/LombiqBot
#
#                                     actor_avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/84946696?  ...
# 1  https://avatars.githubusercontent.com/u/94089796?  ...
# 2  https://avatars.githubusercontent.com/u/49699333?  ...
# 3  https://avatars.githubusercontent.com/u/29518524?  ...
# 4  https://avatars.githubusercontent.com/u/41898282?  ...
# 5  https://avatars.githubusercontent.com/u/75331162?  ...
# 6   https://avatars.githubusercontent.com/u/1597813?  ...
# 7  https://avatars.githubusercontent.com/u/51066424?  ...
# 8  https://avatars.githubusercontent.com/u/92156529?  ...
# 9   https://avatars.githubusercontent.com/u/8517910?  ...
#
#                                      payload_commits  \
# 0                                                NaN
# 1  [{'sha': '992d71ee643aa36236d92e5f7f0c38ff723c...
# 2                                                NaN
# 3                                                NaN
# 4  [{'sha': 'c03a6f45d2f86bbd63a6c18d3d0d2245e22a...
# 5  [{'sha': '42dc187d8dab9986f370e42f939bce74d95c...
# 6                                                NaN
# 7  [{'sha': 'd58370babbc95cd96eaccb02d6d869b725af...
# 8  [{'sha': '71e6294b60a252fe5fe5d08cf3a97fa7630f...
# 9                                                 []
#
#                                       payload_forkee payload_ref_type  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3  {'id': 435457961, 'node_id': 'R_kgDOGfSPqQ', '...              NaN
# 4                                                NaN              NaN
# 5                                                NaN              NaN
# 6  {'id': 435457960, 'node_id': 'R_kgDOGfSPqA', '...              NaN
# 7                                                NaN              NaN
# 8                                                NaN              NaN
# 9                                                NaN              NaN
#
#   payload_master_branch payload_description payload_pusher_type  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# 5                   NaN                 NaN                 NaN
# 6                   NaN                 NaN                 NaN
# 7                   NaN                 NaN                 NaN
# 8                   NaN                 NaN                 NaN
# 9                   NaN                 NaN                 NaN
#
#   payload_member    repo_id                              repo_name  \
# 0            NaN  423445616             mikexia930/xDatetimePicker
# 1            NaN  433661455                             npmds/fcms
# 2            NaN  317622239                     FFHixio/nodejs.dev
# 3            NaN  233046875  n3oney/discord.js-typescript-template
# 4            NaN  371146906        krb2162/flat-demo-bitcoin-price
# 5            NaN  432932764                         jonyg80/ht-num
# 6            NaN  425881518              vvs-finance/vvs-swap-core
# 7            NaN  429335712                  MABilton/arraytainers
# 8            NaN  424184805             ElisaDESOUSA/SiteSport-Air
# 9            NaN  265094441              Lombiq/UI-Testing-Toolbox
#
#                                             repo_url
# 0  https://api.github.com/repos/mikexia930/xDatet...
# 1            https://api.github.com/repos/npmds/fcms
# 2    https://api.github.com/repos/FFHixio/nodejs.dev
# 3  https://api.github.com/repos/n3oney/discord.js...
# 4  https://api.github.com/repos/krb2162/flat-demo...
# 5        https://api.github.com/repos/jonyg80/ht-num
# 6  https://api.github.com/repos/vvs-finance/vvs-s...
# 7  https://api.github.com/repos/MABilton/arraytai...
# 8  https://api.github.com/repos/ElisaDESOUSA/Site...
# 9  https://api.github.com/repos/Lombiq/UI-Testing...
#
# [10 rows x 34 columns]

# %%
results = response.json()
flattened_data = pd.json_normalize(results)
flattened_data
# Out:
#              id              type  public            created_at  actor.id  \
# 0   19197514593  PullRequestEvent    True  2021-12-06T10:44:56Z  84946696
# 1   19197514562         PushEvent    True  2021-12-06T10:44:56Z  94089796
# 2   19197514567  PullRequestEvent    True  2021-12-06T10:44:56Z  49699333
# 3   19197514585         ForkEvent    True  2021-12-06T10:44:56Z  29518524
# 4   19197514568         PushEvent    True  2021-12-06T10:44:56Z  41898282
# 5   19197514549         PushEvent    True  2021-12-06T10:44:56Z  75331162
# 6   19197514565         ForkEvent    True  2021-12-06T10:44:56Z   1597813
# 7   19197514552         PushEvent    True  2021-12-06T10:44:56Z  51066424
# 8   19197514494         PushEvent    True  2021-12-06T10:44:56Z  92156529
# 9   19197514528         PushEvent    True  2021-12-06T10:44:56Z   8517910
# 10  19197514492         PushEvent    True  2021-12-06T10:44:56Z  41898282
# 11  19197514505       CreateEvent    True  2021-12-06T10:44:56Z  49699333
# 12  19197514519       DeleteEvent    True  2021-12-06T10:44:56Z  27630111
# 13  19197514461         PushEvent    True  2021-12-06T10:44:56Z   1841518
# 14  19197514506         ForkEvent    True  2021-12-06T10:44:56Z  70897018
# 15  19197514467       CreateEvent    True  2021-12-06T10:44:56Z  78304363
# 16  19197514462         PushEvent    True  2021-12-06T10:44:56Z  92907907
# 17  19197514465         PushEvent    True  2021-12-06T10:44:56Z   8517910
# 18  19197514460         PushEvent    True  2021-12-06T10:44:56Z  20199124
# 19  19197514454        WatchEvent    True  2021-12-06T10:44:56Z  41519060
# 20  19197514457         PushEvent    True  2021-12-06T10:44:56Z   1405982
# 21  19197514452       CreateEvent    True  2021-12-06T10:44:56Z    748828
# 22  19197514443  PullRequestEvent    True  2021-12-06T10:44:56Z  27630111
# 23  19197514401         PushEvent    True  2021-12-06T10:44:56Z  91871778
# 24  19197514421         PushEvent    True  2021-12-06T10:44:56Z  43733305
# 25  19197514450       MemberEvent    True  2021-12-06T10:44:56Z  32807671
# 26  19197514415         PushEvent    True  2021-12-06T10:44:56Z  82944428
# 27  19197514422         PushEvent    True  2021-12-06T10:44:56Z   8517910
# 28  19197514430         PushEvent    True  2021-12-06T10:44:56Z  29708070
# 29  19197514429         PushEvent    True  2021-12-06T10:44:56Z  90237091
#
#             actor.login  actor.display_login actor.gravatar_id  \
# 0            mikexia930           mikexia930
# 1                 npmds                npmds
# 2       dependabot[bot]           dependabot
# 3             PluginYML            PluginYML
# 4   github-actions[bot]       github-actions
# 5               jonyg80              jonyg80
# 6                 Triex                Triex
# 7              MABilton             MABilton
# 8        JupiterD-aurel       JupiterD-aurel
# 9             LombiqBot            LombiqBot
# 10  github-actions[bot]       github-actions
# 11      dependabot[bot]           dependabot
# 12             andpodob             andpodob
# 13           yannrichet           yannrichet
# 14             AxelWadd             AxelWadd
# 15  El-Mokhtar-AIssaoui  El-Mokhtar-AIssaoui
# 16                 znyt                 znyt
# 17            LombiqBot            LombiqBot
# 18      AtsushiTanimoto      AtsushiTanimoto
# 19      treva-123mutebi      treva-123mutebi
# 20          demianmnave          demianmnave
# 21              tk0miya              tk0miya
# 22             andpodob             andpodob
# 23             Marta129             Marta129
# 24             yanonono             yanonono
# 25             hphuc613             hphuc613
# 26             Tashar02             Tashar02
# 27            LombiqBot            LombiqBot
# 28              AMTitan              AMTitan
# 29             kcheykim             kcheykim
#
#                                            actor.url  \
# 0            https://api.github.com/users/mikexia930
# 1                 https://api.github.com/users/npmds
# 2       https://api.github.com/users/dependabot[bot]
# 3             https://api.github.com/users/PluginYML
# 4   https://api.github.com/users/github-actions[bot]
# 5               https://api.github.com/users/jonyg80
# 6                 https://api.github.com/users/Triex
# 7              https://api.github.com/users/MABilton
# 8        https://api.github.com/users/JupiterD-aurel
# 9             https://api.github.com/users/LombiqBot
# 10  https://api.github.com/users/github-actions[bot]
# 11      https://api.github.com/users/dependabot[bot]
# 12             https://api.github.com/users/andpodob
# 13           https://api.github.com/users/yannrichet
# 14             https://api.github.com/users/AxelWadd
# 15  https://api.github.com/users/El-Mokhtar-AIssaoui
# 16                 https://api.github.com/users/znyt
# 17            https://api.github.com/users/LombiqBot
# 18      https://api.github.com/users/AtsushiTanimoto
# 19      https://api.github.com/users/treva-123mutebi
# 20          https://api.github.com/users/demianmnave
# 21              https://api.github.com/users/tk0miya
# 22             https://api.github.com/users/andpodob
# 23             https://api.github.com/users/Marta129
# 24             https://api.github.com/users/yanonono
# 25             https://api.github.com/users/hphuc613
# 26             https://api.github.com/users/Tashar02
# 27            https://api.github.com/users/LombiqBot
# 28              https://api.github.com/users/AMTitan
# 29             https://api.github.com/users/kcheykim
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/84946696?  ...
# 1   https://avatars.githubusercontent.com/u/94089796?  ...
# 2   https://avatars.githubusercontent.com/u/49699333?  ...
# 3   https://avatars.githubusercontent.com/u/29518524?  ...
# 4   https://avatars.githubusercontent.com/u/41898282?  ...
# 5   https://avatars.githubusercontent.com/u/75331162?  ...
# 6    https://avatars.githubusercontent.com/u/1597813?  ...
# 7   https://avatars.githubusercontent.com/u/51066424?  ...
# 8   https://avatars.githubusercontent.com/u/92156529?  ...
# 9    https://avatars.githubusercontent.com/u/8517910?  ...
# 10  https://avatars.githubusercontent.com/u/41898282?  ...
# 11  https://avatars.githubusercontent.com/u/49699333?  ...
# 12  https://avatars.githubusercontent.com/u/27630111?  ...
# 13   https://avatars.githubusercontent.com/u/1841518?  ...
# 14  https://avatars.githubusercontent.com/u/70897018?  ...
# 15  https://avatars.githubusercontent.com/u/78304363?  ...
# 16  https://avatars.githubusercontent.com/u/92907907?  ...
# 17   https://avatars.githubusercontent.com/u/8517910?  ...
# 18  https://avatars.githubusercontent.com/u/20199124?  ...
# 19  https://avatars.githubusercontent.com/u/41519060?  ...
# 20   https://avatars.githubusercontent.com/u/1405982?  ...
# 21    https://avatars.githubusercontent.com/u/748828?  ...
# 22  https://avatars.githubusercontent.com/u/27630111?  ...
# 23  https://avatars.githubusercontent.com/u/91871778?  ...
# 24  https://avatars.githubusercontent.com/u/43733305?  ...
# 25  https://avatars.githubusercontent.com/u/32807671?  ...
# 26  https://avatars.githubusercontent.com/u/82944428?  ...
# 27   https://avatars.githubusercontent.com/u/8517910?  ...
# 28  https://avatars.githubusercontent.com/u/29708070?  ...
# 29  https://avatars.githubusercontent.com/u/90237091?  ...
#
#                          payload.member.following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/khanhdang27/follo...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                              payload.member.gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/khanhdang27/gists...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                            payload.member.starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/khanhdang27/starr...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                      payload.member.subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/khanhdang27/subsc...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                  payload.member.organizations_url  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25  https://api.github.com/users/khanhdang27/orgs
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
#
#                           payload.member.repos_url  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25  https://api.github.com/users/khanhdang27/repos
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
#
#                             payload.member.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/khanhdang27/event...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                    payload.member.received_events_url payload.member.type  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
# 24                                                NaN                 NaN
# 25  https://api.github.com/users/khanhdang27/recei...                User
# 26                                                NaN                 NaN
# 27                                                NaN                 NaN
# 28                                                NaN                 NaN
# 29                                                NaN                 NaN
#
#    payload.member.site_admin
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                     False
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
#
# [30 rows x 475 columns]
