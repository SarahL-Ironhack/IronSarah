# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv(r'C:\Users\Sarah\Documents\IronSarah\Project 4\diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#        Unnamed: 0.1         carat         depth         table         price  \
# count   53932.00000  53932.000000  53932.000000  53932.000000  53932.000000
# mean    26970.48804      0.797879     61.749336     57.457029   3932.136079
# std     15571.46971      0.473986      1.432514      2.234064   3988.734835
# min         1.00000      0.200000     43.000000     43.000000    326.000000
# 25%     13485.75000      0.400000     61.000000     56.000000    949.750000
# 50%     26971.50000      0.700000     61.800000     57.000000   2401.000000
# 75%     40455.25000      1.040000     62.500000     59.000000   5324.000000
# max     53940.00000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z  clarity_score   color_score  \
# count  53932.000000  53932.000000  53932.000000   53932.000000  53932.000000
# mean       5.732007      5.734141      3.539735       3.051101      3.405789
# std        1.119670      1.113272      0.692051       1.647109      1.701165
# min        3.730000      3.680000      1.070000       0.000000      0.000000
# 25%        4.710000      4.720000      2.910000       2.000000      2.000000
# 50%        5.700000      5.710000      3.530000       3.000000      3.000000
# 75%        6.540000      6.540000      4.040000       4.000000      5.000000
# max       10.740000     19.278421      8.060000       7.000000      6.000000
#
#              depth2
# count  53932.000000
# mean      61.748240
# std        1.504792
# min       16.100000
# 25%       61.000000
# 50%       61.800000
# 75%       62.500000
# max      100.700000

# %%
#your comments here

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here
"""
Features that should affect price most :
- Carat = the more carat there is the more precious the diamond is
- depth = same logic
- color and/or clarity = maybe some coloured diamonds are more rare than other, which would increase their price
"""
# Out:
# '\nFeatures that should affect price most :\n- Carat = the more carat there is the more precious the diamond is\n- depth = same logic\n- color and/or clarity = maybe some coloured diamonds are more rare than other, which would increase their price\n'

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.pivot_table(index = ['color'], fill_value=0)
# Out:
#        Unnamed: 0.1     carat  clarity_score  color_score      depth  \
# color
# D      28119.444937  0.657715       2.691025            6  61.698066
# E      28791.322139  0.657867       2.969889            5  61.662090
# F      27621.585177  0.736509       3.134605            4  61.694087
# G      27726.789637  0.771088       3.463419            3  61.757449
# H      24587.229704  0.911627       2.933871            2  61.836557
# I      24951.123202  1.026927       2.964035            1  61.846385
# J      23538.721866  1.162137       2.776353            0  61.887215
#
#           depth2        price      table         x         y         z
# color
# D      61.700221  3168.106436  57.404355  5.417851  5.421928  3.343320
# E      61.653608  3076.752475  57.491201  5.411580  5.416949  3.337767
# F      61.689234  3725.091938  57.433148  5.616727  5.620529  3.465938
# G      61.764562  3998.145173  57.288060  5.678549  5.681198  3.507966
# H      61.834751  4484.958805  57.518176  5.984776  5.981484  3.699147
# I      61.840428  5091.874954  57.577278  6.222826  6.222730  3.846368
# J      61.895299  5323.818020  57.812393  6.519338  6.518105  4.033251

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here
"""
D was supposed to be the best color, and J the worse
Here D has the lowest mean price whereas J has the highest mean price 
The price does not seem related to the color 
"""
# Out:
# '\nD was supposed to be the best color, and J the worse\nHere D has the lowest mean price whereas J has the highest mean price \nThe price does not seem related to the color \n'

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
diamonds.sort_values(by=['price'], inplace=True)

diamonds.groupby('color').agg('mean').plot(
    y='price',kind='bar', title = 'Mean price per color', ylabel = 'Price', figsize =(10,8))
#diamonds.plot(x = 'color', y = 'price')
# Out:
# <AxesSubplot:title={'center':'Mean price per color'}, xlabel='color', ylabel='Price'>

# %%
#your comments here
"""
Can clearly see the "worse" color (D) has almost de lowest average price
vs. highest average price for J "best" color
"""

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('carat').agg('mean')
# Out:
#        Unnamed: 0.1      depth      table         price          x          y  \
# carat
# 0.20   28965.166667  61.100000  59.333333    365.166667   3.786667   3.753333
# 0.21   34659.000000  60.511111  58.444444    380.222222   3.874444   3.837778
# 0.22    6948.600000  61.620000  60.400000    391.400000   3.898000   3.848000
# 0.23   35756.993174  61.426621  58.034130    486.143345   3.946382   3.973379
# 0.24   31885.330709  61.599213  57.488189    505.185039   3.990157   4.019331
# ...             ...        ...        ...           ...        ...        ...
# 4.00   26445.000000  63.300000  58.000000  15984.000000  10.010000   9.940000
# 4.01   25999.500000  61.750000  61.500000  15223.000000  10.080000  10.020000
# 4.13   27131.000000  64.800000  61.000000  17329.000000  10.000000   9.850000
# 4.50   27631.000000  65.800000  58.000000  18531.000000  10.230000  10.160000
# 5.01   27416.000000  65.500000  59.000000  18018.000000  10.740000  10.540000
#
#               z  clarity_score  color_score     depth2
# carat
# 0.20   2.303333       2.833333     5.166667  61.100000
# 0.21   2.332222       2.666667     5.444444  60.511111
# 0.22   2.386000       2.600000     4.800000  61.620000
# 0.23   2.431468       4.901024     4.518771  61.419454
# 0.24   2.465591       4.972441     4.185039  61.579921
# ...         ...            ...          ...        ...
# 4.00   6.310000       0.000000     1.000000  63.300000
# 4.01   6.205000       0.000000     0.500000  61.750000
# 4.13   6.430000       0.000000     2.000000  64.800000
# 4.50   6.720000       0.000000     0.000000  65.900000
# 5.01   6.980000       0.000000     0.000000  65.600000
#
# [273 rows x 10 columns]

# %%
#your comments
"""
there are 273 different means to be studied
however we clearly see the mean price is at its highest for the highest Carat weight
also the clarity score is at 0 for these diamonds 
"""

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
hist_carat=diamonds.groupby('carat').agg('mean').reset_index()
hist_carat
# Out:
#      carat  Unnamed: 0.1      depth      table         price          x  \
# 0     0.20  28965.166667  61.100000  59.333333    365.166667   3.786667
# 1     0.21  34659.000000  60.511111  58.444444    380.222222   3.874444
# 2     0.22   6948.600000  61.620000  60.400000    391.400000   3.898000
# 3     0.23  35756.993174  61.426621  58.034130    486.143345   3.946382
# 4     0.24  31885.330709  61.599213  57.488189    505.185039   3.990157
# ..     ...           ...        ...        ...           ...        ...
# 268   4.00  26445.000000  63.300000  58.000000  15984.000000  10.010000
# 269   4.01  25999.500000  61.750000  61.500000  15223.000000  10.080000
# 270   4.13  27131.000000  64.800000  61.000000  17329.000000  10.000000
# 271   4.50  27631.000000  65.800000  58.000000  18531.000000  10.230000
# 272   5.01  27416.000000  65.500000  59.000000  18018.000000  10.740000
#
#              y         z  clarity_score  color_score     depth2
# 0     3.753333  2.303333       2.833333     5.166667  61.100000
# 1     3.837778  2.332222       2.666667     5.444444  60.511111
# 2     3.848000  2.386000       2.600000     4.800000  61.620000
# 3     3.973379  2.431468       4.901024     4.518771  61.419454
# 4     4.019331  2.465591       4.972441     4.185039  61.579921
# ..         ...       ...            ...          ...        ...
# 268   9.940000  6.310000       0.000000     1.000000  63.300000
# 269  10.020000  6.205000       0.000000     0.500000  61.750000
# 270   9.850000  6.430000       0.000000     2.000000  64.800000
# 271  10.160000  6.720000       0.000000     0.000000  65.900000
# 272  10.540000  6.980000       0.000000     0.000000  65.600000
#
# [273 rows x 11 columns]

# %%
import seaborn as sns
sns.histplot(data=hist_carat,x=	"carat")
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Count'>

# %%
hist_carat.plot(x='carat',y='price',kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('table').agg('mean').reset_index()
# Out:
#      table  Unnamed: 0.1   carat  depth    price      x      y      z  \
# 0     43.0      11369.00  1.0400  62.90   4997.0  6.450  6.410  4.040
# 1     44.0      35634.00  0.2900  62.80    474.0  4.200  4.240  2.650
# 2     49.0      14341.00  0.6500  64.25   2290.5  5.355  5.320  3.425
# 3     50.0      16299.50  1.5100  61.50   8995.5  7.380  7.295  4.510
# 4     50.1       3239.00  0.9400  66.00   3353.0  6.130  6.170  4.060
# ..     ...           ...     ...    ...      ...    ...    ...    ...
# 122   71.0      44939.00  0.6800  58.00   1633.0  5.850  5.700  3.350
# 123   73.0      51622.75  0.6025  68.90   2406.5  5.520  5.465  3.745
# 124   76.0      51343.00  0.7900  65.30   2362.0  5.520  5.130  3.350
# 125   79.0      50774.00  0.8100  68.80   2301.0  5.260  5.200  3.580
# 126   95.0      24933.00  2.0100  58.60  13387.0  8.320  8.310  4.870
#
#      clarity_score  color_score  depth2
# 0             4.00          1.0   62.80
# 1             4.00          5.0   62.80
# 2             3.00          3.0   64.25
# 3             2.00          3.0   61.50
# 4             1.00          2.0   66.00
# ..             ...          ...     ...
# 122           2.00          3.0   58.00
# 123           3.25          4.5   68.75
# 124           2.00          3.0   62.90
# 125           1.00          4.0   68.50
# 126           2.00          4.0   58.60
#
# [127 rows x 11 columns]

# %%
#your comments here
"""
NC
"""

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here

# %%
#your comments here
diamonds.groupby('clarity').agg('mean').reset_index()
# Out:
#   clarity  Unnamed: 0.1     carat      depth      table        price  \
# 0      I1  22419.002699  1.283846  62.734278  58.303779  3924.168691
# 1      IF  33591.562011  0.505123  61.510615  56.507207  2864.839106
# 2     SI1  25585.839112  0.850482  61.853042  57.662541  3996.001148
# 3     SI2  21448.339826  1.077602  61.771567  57.926823  5062.267356
# 4     VS1  27934.582987  0.727108  61.667968  57.313966  3839.144308
# 5     VS2  27833.538267  0.763850  61.724249  57.418040  3924.166204
# 6    VVS1  32403.857417  0.503131  61.624521  56.883881  2519.512315
# 7    VVS2  31323.464272  0.596202  61.663778  57.024990  3283.737071
#
#           x         y         z  clarity_score  color_score     depth2
# 0  6.761093  6.709379  4.224683            0.0     2.968961  62.751417
# 1  4.968402  4.989827  3.061659            7.0     3.101676  61.502570
# 2  5.888383  5.888256  3.640636            2.0     3.448450  61.848993
# 3  6.404157  6.395579  3.952642            1.0     3.469967  61.776964
# 4  5.572860  5.580017  3.437924            4.0     3.161812  61.658507
# 5  5.658633  5.659782  3.492788            3.0     3.494370  61.727056
# 6  4.961721  4.976437  3.062132            6.0     3.350848  61.630049
# 7  5.218454  5.232118  3.221465            5.0     3.569483  61.657580

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
"""
The depth does not seem to have a direct link with clarity 
the highest price is linked to SI2, the second worse clarity rate 
SI2 also has the most carat weight, along with I1 (worse clarity rate)
"""

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here
"""
x-price
x-carat
carat distribution
price distribution
"""

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
"""
we find a strong correlation between x,y,z and depth which is quite natural
Also a high correlation between x,y,z and carat and x,y,z and price
"""

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# C:\Users\Sarah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493658995804617

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
"""
r2 represents de coefficient of determination, the closer it is to 1, the better the regression 
predictions fit the data
Here the value is r2, meaning the prediction are good
"""

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here
"""
No other features to be checked
"""
# Out:
# '\nNo other features to be checked\n'

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
